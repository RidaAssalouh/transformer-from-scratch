# %% [markdown]
# <h1 style="text-align: center;">Building a Transformer From Scratch</h1>
# <h3 style="text-align: center;">by Rida Assalouh</h3>

# %% [markdown]
# Given an input matrix $X \in \mathbb{R}^{T \times d_{\text{model}}}$ and projection matrices  $W_Q, W_K, W_V \in \mathbb{R}^{d_{\text{model}} \times d_k}$,
# we compute the query, key, and value representations as
#
# $$
# Q = X W_Q, \qquad
# K = X W_K, \qquad
# V = X W_V,
# $$
#
# each in $\mathbb{R}^{T \times d_k}$.
# In this example, we take $d_v = d_k$.
#
# The self-attention output, which produces updated token representations in  $\mathbb{R}^{T \times d_v}$, is given by
#
# $$
# \mathrm{Attention}(Q, K, V)
#    = \mathrm{softmax}\!\left(\frac{QK^{\mathsf T}}{\sqrt{d_k}}\right)V
# $$
#
# The matrix
#
# $$
# \mathrm{softmax}\!\left(\frac{QK^{\mathsf T}}{\sqrt{d_k}}\right)
#    \in \mathbb{R}^{T \times T}
# $$
#
# contains all pairwise attention weights between tokens, describing how much each position attends to every other one.
#
# In causal language models, this matrix is **masked** to prevent a token from attending to future tokens.
# This enforces the autoregressive property: the model may only use past context, never future information, exactly as required in systems like ChatGPT.

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn

# %%
def scaled_dot_product_attention(Q, K, V):
    """
    Compute scaled dot-product attention.
    Q: (batch_size, n_heads, T_q, d_k)
    K: (batch_size, n_heads, T_k, d_k)
    V: (batch_size, n_heads, T_k, d_v)
    Returns:
      output: (batch_size, n_heads, T_q, d_v)
      attn_weights: (batch_size, n_heads, T_q, T_k)"""

    d_k = Q.shape[-1]
    KT = K.transpose(-2,-1)
    attn_weights = F.softmax(torch.matmul(Q, KT)/Q.size(-1)**0.5, dim=-1)
    output = torch.matmul(attn_weights, V)

    return output, attn_weights

# %% [markdown]
# In the multi-head attention setting, let $h$ be the number of heads and define  $Q_i = X W_i^Q$ for head $i = 1, \dots, h$
#
# We set $d_k = d_q = d_v = d_{\text{model}} / h$.
# Each projection matrix $W_i^Q \in \mathbb{R}^{d_{\text{model}} \times d_k}$ is specific to its head.
#
# The output of each head is computed as
#
# $$
# E_i = \mathrm{softmax}\!\left(\frac{Q_i K_i^{T}}{\sqrt{d_k}}\right)V_i
# \in \mathbb{R}^{T \times d_k}
# $$
#
# Finally, the outputs of all heads are concatenated and projected using $W_O$:
#
# $$
# \mathrm{MultiHead}(X) = [E_1, \dots, E_h]\, W_O
# $$
#
# where $W_O \in \mathbb{R}^{d_{\text{model}} \times d_{\text{model}}}$, and therefore $\mathrm{MultiHead}(X) \in \mathbb{R}^{T \times d_{\text{model}}}$.

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, n_heads):
        super().__init__()

        self.d_model = d_model
        self.n_heads = n_heads

        self.d_k = d_model // n_heads

        self.W_q = nn.Linear(d_model, d_model) # this W_q is a concatenation of all W_qs [W_q_1, ..., W_q_h] where h=n_heads
        self.W_k = nn.Linear(d_model, d_model) # same
        self.W_v = nn.Linear(d_model, d_model) # same

        self.W_o = nn.Linear(d_model, d_model)

    def forward(self, X):
          """
          X: (batch_size, T, d_model)
          Returns: (batch_size, T, d_model)
          """
          batch_size, T, _ = X.shape

          Q = self.W_q(X) # for each batch b Q[b] is the concatenation  [X . W_q_1, ..., X . W_q_h] so Q shape is (batch_size, T, d_model)
          K = self.W_k(X) # same
          V = self.W_v(X) # same

          Q = Q.view(batch_size, T, self.n_heads, self.d_k).transpose(1,2) # (batch_size, n_heads, T, d_k)
          K = K.view(batch_size, T, self.n_heads, self.d_k).transpose(1,2)
          V = V.view(batch_size, T, self.n_heads, self.d_k).transpose(1,2)

          outputs, _ = scaled_dot_product_attention(Q, K, V) # (batch_size, n_heads, T, d_v)
          outputs = outputs.transpose(1,2).contiguous().view(batch_size, T, self.d_model) # (batch_size, T, d_model)

          return self.W_o(outputs) # (batch_size, T, d_model)

# %%
encoder = MultiHeadAttention(1024, 8)
X = torch.randn(1, 20, 1024)

print(encoder(X).shape)
# Out:
# torch.Size([1, 20, 1024])

# %% [markdown]
# After multi-head attention, instead of passing the output directly forward, we add a **skip connection** and apply **layer normalization**:
#
# $$
# X' = \text{LayerNorm}(X + \text{MultiHeadAttention}(X))
# $$
#
# Next, we feed $X'$ into an MLP, and again apply a skip connection followed by normalization:
#
# $$
# X_{\text{transformerblock}} = \text{LayerNorm}(X' + \text{MLP}(X'))
# $$

# %%
class TransformerBlock(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()

        self.mha = MultiHeadAttention(d_model, n_heads)
        self.norm1 = nn.LayerNorm(d_model)
        self.dropout_att =  nn.Dropout(dropout)
        self.ffn = nn.Sequential(
              nn.Linear(d_model, d_ff),
              nn.ReLU(),
              nn.Linear(d_ff, d_model)
            )
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout_MLP =  nn.Dropout(dropout)


    def forward(self, X):
        X_attention = self.mha(X)
        X_att_norm = self.norm1(X + self.dropout_att(X_attention))
        X_ff = self.ffn(X_att_norm)
        X = self.norm2(X_att_norm + self.dropout_MLP(X_ff))
        return X

# %%
transformer_block = TransformerBlock(d_model=512, n_heads=8, d_ff=2048)
X = torch.randn(2, 45, 512)
X = transformer_block(X)
print(X.shape)
# Out:
# torch.Size([2, 45, 512])

# %% [markdown]
# All of what was done until now represents a single transformer block, which can be seen as a function of the input $X$, denoted $f_{\theta}(X)$.
# In practice, we sequentially stack multiple transformer blocks, so that the full encoder is the composition of these functions applied to the initial input embeddings   $X \in \mathbb{R}^{\text{batch\_size} \times T \times d_{\text{model}}}$
#
# $$
# f_{\theta_N}\big(f_{\theta_{N-1}}(\dots f_{\theta_1}(X)\dots)\big)
# $$
#
# We also add **positional encodings** to retain order information.
# For position $t \in \{1, \dots, T\}$ and dimension $k \in \{1, \dots, d_{\text{model}}\}$, the sinusoidal positional encoding is defined as:
#
# $$
# PE(t)_k =
# \begin{cases}
# \sin\Big(\frac{t}{10000^{k / d_{\text{model}}}}\Big), & \text{if $k$ is even} \\[2mm]
# \cos\Big(\frac{t}{10000^{(k-1) / d_{\text{model}}}}\Big), & \text{if $k$ is odd}
# \end{cases}
# $$
#
# - The term $10000^{k/d_\text{model}}$ ensures different frequencies across dimensions.
#
# ---
#
# ### Code details:
#
# - Input: integers (token IDs) $\in [0, V-1]$.
# - The embedding matrix outputs dense vectors of size $d_{\text{model}}$.
# - Implemented in PyTorch as `nn.Embedding(vocab_size, d_model)`.
# - Equivalence: it is mathematically equivalent to multiplying a one-hot encoded vector of size $V$ by a linear layer $W \in \mathbb{R}^{V \times d_{\text{model}}}$, but much more efficient because we don’t need to construct the huge one-hot vector.
#
# ---
#
# ### 1. Learned positional embeddings
#
# - Create an `nn.Embedding(max_seq_len, d_model)` in the constructor.
# - These embeddings are **learned parameters** updated during training.
#
# ### 2. Sinusoidal positional embeddings
#
# - These are **fixed, deterministic values**.
# - Precompute them in the constructor for the maximum sequence length and store in `self.pos_embedding`, then slice in `forward()` according to the input length.
#
# - Optimization tip: **avoid while loops**; use broadcasting to vectorize computations. This allows parallelization on GPUs, unlike loops.

# %% [markdown]
# ## **Now let's build the whole transformer encoder**

# %% [markdown]
# **A very useful idea for the classification task we will study at the end** is to initialize the embedding matrix with **BERT pretrained embeddings**.
# In one of the experiments, this increased the accuracy from **0.80 to 0.85**.
#
# This is essentially like a  **BERT finetuning** adapted to our model.
#
# I added a parameter `embedding_initialization` (default: `"bert"`) to choose whether we use **BERT embeddings** or a **random initialization**.
#
# We sue sinusoidal positional encodings.

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, V, N, d_model, n_heads, d_ff, max_seq_len, embedding_initialization='BERT', dropout=0.1):
        super().__init__()

        if embedding_initialization == 'BERT':
          bert = AutoModel.from_pretrained("bert-base-uncased")
          pretrained_emb = bert.embeddings.word_embeddings.weight  # shape (30522, 768)
          if d_model != 768: # Project embeddings to your d_model if needed
              projection = nn.Linear(768, d_model, bias=False)
              with torch.no_grad():
                  projected_emb = projection(pretrained_emb)  # shape (30522, d_model)
          else:
              projected_emb = pretrained_emb
          self.token_embedding = nn.Embedding.from_pretrained(projected_emb, freeze=False)
        
        elif embedding_initialization == 'random':
          self.token_embedding = nn.Embedding(V, d_model)
        
        else:
          raise ValueError(f"Parameter 'embedding_initialization' must be either 'BERT' or 'random', got '{embedding_initialization}'")

        positions = torch.arange(max_seq_len).unsqueeze(1)
        dims = torch.arange(d_model).unsqueeze(0)
        angles = 1 / 10000**((dims//2)*2 / d_model) # substract one to odd indexes
        PE = torch.zeros(max_seq_len, d_model)
        PE[:, 0::2] = torch.sin(positions * angles[:, 0::2]) # broadcasting so things are vectorized and parallelizable on GPU
        PE[:, 1::2] = torch.cos(positions * angles[:, 1::2])
        self.register_buffer('pos_embedding', PE)

        self.layers = nn.ModuleList([TransformerBlock(d_model, n_heads, d_ff) for _ in range(N)])

        self.dropout = nn.Dropout(dropout)

    def forward(self, X):
        """
        X: (batch_size, T)  # token IDs (we suppose X is already preprocessed such that T < max_seq_len)
        """
        _ , T = X.shape
        X = self.token_embedding(X) # now X is (batch size, T, d_model)
        X = X + self.pos_embedding[:T, :].unsqueeze(0)
        X = self.dropout(X)

        for layer in self.layers:
          X = layer(X)

        return X

# %% [markdown]
# Now let's initiliaze the embedding matrix by Bert embeddings:

# %%
model = TransformerEncoder(100, 6, 512, 8, 1024, 16)
X = torch.zeros(4, 15, dtype=torch.long)
print(model(X).shape)
# Out:
# torch.Size([4, 15, 512])

# %% [markdown]
# We may also apply dropout in other places within the transformer block:
#
# $$
# X' = \text{LayerNorm}\big(X + \text{Dropout}(\text{MultiHeadAttention}(X))\big)
# $$
#
# and
#
# $$
# X_{\text{transformerblock}}
# = \text{LayerNorm}\big(X' + \text{Dropout}(\text{MLP}(X'))\big)
# $$

# %% [markdown]
# # **Using a transformer encoder for sentence classification**

# %% [markdown]
# At the end of the transformer, I use a linear layer to produce the predicted logits.
# This layer takes as input the embedding of the **[CLS]** token, which is placed as the **first token** in every input sequence, both during training and testing.

# %%
class TransformerClassifierCLS(nn.Module):
    def __init__(self, encoder, d_model, num_classes):
        super().__init__()
        self.encoder = encoder

        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, X):
        """
        X: (batch_size, T) token IDs,
           make sure the first token in each sequence is the [CLS] token
        """
        enc_out = self.encoder(X) # batch_size, T, d_model

        cls_emb = enc_out[:, 0, :] # batch_size, d_model

        logits = self.fc(cls_emb) # batch_size, num_classes

        return logits

# %%
encoder = TransformerEncoder(200, 6, 512, 8, 1024, 500)
classifier = TransformerClassifierCLS(encoder, 512, 2)
X = torch.zeros(64 ,13, dtype=torch.long)

print(classifier(X).shape)
# Out:
# torch.Size([64, 2])

# %% [markdown]
# ## **Let's Load imdb movies reviews dataset from huggingface:**

# %%
from datasets import load_dataset

raw_dataset = load_dataset("imdb")
train_texts = raw_dataset['train']['text']
train_labels = raw_dataset['train']['label']
# Out:
# Generating train split: 100%|██████████| 25000/25000 [00:00<00:00, 40023.62 examples/s]
# Generating test split: 100%|██████████| 25000/25000 [00:00<00:00, 46103.17 examples/s]
# Generating unsupervised split: 100%|██████████| 50000/50000 [00:01<00:00, 44090.39 examples/s]

# %%
avg_len = sum(len(text.split()) for text in train_texts) / len(train_texts)
print("The average number of words in the samples in the dataset is : ", avg_len)
# Out:
# The average number of words in the samples in the dataset is :  233.7872

# %%
print("number of samples in the training dataset :", len(raw_dataset['train']['text']))
# Out:
# number of samples in the training dataset : 25000

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# %%
sentence = ["", "hey bro how is Inezgane"]
encoding = tokenizer(
    sentence,
    truncation=True,
    padding='max_length',
    max_length=10,
    add_special_tokens=True,
)
print(encoding['input_ids'])

print([tokenizer.decode(encoding['input_ids'][i]) for i in range(len(sentence))])
print(tokenizer.decode(101))
# Out:
# [[101, 102, 0, 0, 0, 0, 0, 0, 0, 0], [101, 4931, 22953, 2129, 2003, 1999, 9351, 5289, 2063, 102]]
# ['[CLS] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]', '[CLS] hey bro how is inezgane [SEP]']
# [CLS]

# %%
tokenizer.vocab_size
# Out:
# 30522

# %%
# # Parameters
# V = tokenizer.vocab_size    # number of tokens used by the tokenizer
# N = 2                       # number of transformer blocks
# d_model = 256               # embedding dimension
# n_heads = 4
# d_ff = 1024                 # typical value is 4 x d_model
# max_seq_len = 256
# dropout = 0.1
# num_epochs = 4
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### **Training Procedure**
#
# We now train our Transformer classifier on the sentence-classification task.
# The full training pipeline includes:
#
# 1. **Tokenization:**
#    We encode the raw text with the BERT tokenizer using `max_seq_len = 256`, applying truncation and padding.
#
# 2. **Dataset and DataLoader:**
#    We construct PyTorch datasets containing:
#    - token IDs (padded sequences)
#    - the corresponding integer labels
#    These are fed into dataloaders for mini-batch training and validation.
#
# 3. **Model construction:**
#    We instantiate our custom `TransformerEncoder` with:
#    - `N` transformer blocks
#    - multi-head attention
#    - optional BERT-initialized token embeddings
#    - sinusoidal positional encodings
#    The encoder is wrapped in a `TransformerClassifierCLS`, which applies a final linear layer on top of the `[CLS]` token embedding.
#
# 4. **Embedding freezing / unfreezing:**
#    If we initialize embeddings with BERT, we optionally **freeze** them during the first training epochs.
#    After a warm-up period (`epochs_to_unfreeze`), we **unfreeze** them to allow fine-tuning.
#
# 5. **Optimization:**
#    We use the AdamW optimizer, standard for Transformer-based training, together with cross-entropy loss.
#    The training loop performs:
#    - forward pass
#    - loss computation
#    - backpropagation
#    - parameter updates
#
# 6. **Validation and checkpointing:**
#    After each epoch, we evaluate on the validation set and compute accuracy.
#    The model achieving the best validation accuracy is saved as `best_model.pth`.
#
# Below is the full training loop:

# %%
import torch.optim as optim
from torch.optim import AdamW

from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer
from sklearn.model_selection import train_test_split

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")


class MyDataset(Dataset):
    def __init__(self, token_ids, labels):
        """
        token_ids: list/array of token sequences (padded to same length) (num_samples, max_seq_len)
        labels: list/array of integer labels (num_samples)
        """
        self.token_ids = torch.tensor(token_ids, dtype=torch.long)
        self.labels = torch.tensor(labels, dtype=torch.long)


    def __len__(self):
      return len(self.token_ids)

    def __getitem__(self, idx):
        return self.token_ids[idx], self.labels[idx]


# Parameters
V = tokenizer.vocab_size    # number of tokens used by the tokenizer
N = 2                       # number of transformer blocks
d_model = 256               # embedding dimension
n_heads = 4
d_ff = 1024                 # typical value is 4 x d_model
max_seq_len = 256
dropout = 0.1
num_epochs = 20
batch_size = 64
initialization = 'BERT'
initially_freeze = True
epochs_to_unfreeze = 1
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Split training data into train + validation
train_and_val_texts = list(raw_dataset['train']['text'])
train_and_val_labels = list(raw_dataset['train']['label'])

train_texts, val_texts, train_labels, val_labels = train_test_split(train_and_val_texts, train_and_val_labels, test_size=0.2, random_state=42)

# Tokenize
train_encodings = tokenizer(
    train_texts,
    truncation=True,
    padding='max_length',
    max_length=max_seq_len,
    add_special_tokens=True,
) # (num_samples, max_seq_len) = (12500, 256)

val_encodings = tokenizer(
    val_texts,
    truncation=True,
    padding='max_length',
    max_length=max_seq_len,
    add_special_tokens=True,
)

train_dataset = MyDataset(train_encodings['input_ids'], train_labels)
val_dataset = MyDataset(val_encodings['input_ids'], val_labels)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

encoder = TransformerEncoder(V, N, d_model, n_heads, d_ff, max_seq_len, initialization, dropout)
model = TransformerClassifierCLS(encoder, d_model=d_model, num_classes=2)
model.to(device)

# Freeze BERT embeddings initially
if initialization == 'BERT' and initially_freeze:
    model.encoder.token_embedding.weight.requires_grad = False
    print("BERT embeddings frozen for initial training")


criterion = nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=5e-5, betas=(0.9, 0.999), weight_decay=1e-5)
best_val_acc = 0.0  # Keep track of the best validation accuracy

for epoch in range(num_epochs):
    model.train()

    if initially_freeze and epoch == epochs_to_unfreeze:  # num of epochs after which we start fine tuning BERT embeddings
        print("Unfreezing BERT embeddings for fine-tuning...")
        model.encoder.token_embedding.weight.requires_grad = True

        # Re-create the optimizer to set different learning rates
        # optimizer = AdamW([
        #     {'params': model.encoder.token_embedding.parameters(), 'lr': 1e-5},  # small LR for embeddings
        #     {'params': [p for n, p in model.named_parameters() if 'token_embedding' not in n], 'lr': 5e-5}
        # ], betas=(0.9, 0.999), weight_decay=1e-5)
        
        optimizer = AdamW(model.parameters(), lr=5e-5, betas=(0.9, 0.999), weight_decay=1e-5)

    running_loss = 0.0
    num_batches = len(train_dataloader)

    for i, (batch_token_ids, batch_labels) in enumerate(train_dataloader, 1):
        batch_token_ids = batch_token_ids.to(device)
        batch_labels = batch_labels.to(device)
        optimizer.zero_grad()
        logits = model(batch_token_ids)
        loss = criterion(logits, batch_labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        print(f"Epoch {epoch+1}/{num_epochs}, Batch {i}/{num_batches}, Loss: {loss.item():.4f}")

    avg_loss = running_loss / num_batches
    print(f"\nEpoch {epoch+1}/{num_epochs} finished, Avg Loss: {avg_loss:.4f}")

    # Validation loop
    model.eval()
    correct = 0
    total = 0
    num_val_batches = len(val_dataloader)

    with torch.no_grad():
        for j, (val_token_ids, val_labels_batch) in enumerate(val_dataloader, 1):
            val_token_ids = val_token_ids.to(device)
            val_labels_batch = val_labels_batch.to(device)
            logits = model(val_token_ids)
            predictions = logits.argmax(dim=1)
            correct += (predictions == val_labels_batch).sum().item()
            total += val_labels_batch.size(0)
            print(f"Epoch {epoch+1}/{num_epochs}, Validation Batch {j}/{num_val_batches}")

    val_acc = correct / total
    print(f"\nValidation Accuracy: {val_acc:.4f}")

    # Save the best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_model.pth")
        print(f"New best model saved with Validation Accuracy: {best_val_acc:.4f}")
# Out:
# BERT embeddings frozen for initial training
# Epoch 1/20, Batch 1/313, Loss: 0.7461
# Epoch 1/20, Batch 2/313, Loss: 0.8210
# Epoch 1/20, Batch 3/313, Loss: 0.7178
# Epoch 1/20, Batch 4/313, Loss: 0.7179
# Epoch 1/20, Batch 5/313, Loss: 0.7318
# Epoch 1/20, Batch 6/313, Loss: 0.7566
# Epoch 1/20, Batch 7/313, Loss: 0.7459
# Epoch 1/20, Batch 8/313, Loss: 0.7213
# Epoch 1/20, Batch 9/313, Loss: 0.7272
# Epoch 1/20, Batch 10/313, Loss: 0.6567
# Epoch 1/20, Batch 11/313, Loss: 0.6984
# Epoch 1/20, Batch 12/313, Loss: 0.7568
# Epoch 1/20, Batch 13/313, Loss: 0.7455
# Epoch 1/20, Batch 14/313, Loss: 0.7379
# Epoch 1/20, Batch 15/313, Loss: 0.7011
# Epoch 1/20, Batch 16/313, Loss: 0.7266
# Epoch 1/20, Batch 17/313, Loss: 0.6591
# Epoch 1/20, Batch 18/313, Loss: 0.7443
# Epoch 1/20, Batch 19/313, Loss: 0.7120
# Epoch 1/20, Batch 20/313, Loss: 0.7363
# Epoch 1/20, Batch 21/313, Loss: 0.7210
# Epoch 1/20, Batch 22/313, Loss: 0.6979
# Epoch 1/20, Batch 23/313, Loss: 0.7556
# Epoch 1/20, Batch 24/313, Loss: 0.6964
# Epoch 1/20, Batch 25/313, Loss: 0.7253
# Epoch 1/20, Batch 26/313, Loss: 0.7105
# Epoch 1/20, Batch 27/313, Loss: 0.7125
# Epoch 1/20, Batch 28/313, Loss: 0.7066
# Epoch 1/20, Batch 29/313, Loss: 0.7141
# Epoch 1/20, Batch 30/313, Loss: 0.6991
# Epoch 1/20, Batch 31/313, Loss: 0.7444
# Epoch 1/20, Batch 32/313, Loss: 0.7569
# Epoch 1/20, Batch 33/313, Loss: 0.7535
# Epoch 1/20, Batch 34/313, Loss: 0.7123
# Epoch 1/20, Batch 35/313, Loss: 0.7114
# Epoch 1/20, Batch 36/313, Loss: 0.7262
# Epoch 1/20, Batch 37/313, Loss: 0.6811
# Epoch 1/20, Batch 38/313, Loss: 0.7135
# Epoch 1/20, Batch 39/313, Loss: 0.7662
# Epoch 1/20, Batch 40/313, Loss: 0.7152
# Epoch 1/20, Batch 41/313, Loss: 0.6610
# Epoch 1/20, Batch 42/313, Loss: 0.6958
# Epoch 1/20, Batch 43/313, Loss: 0.7241
# Epoch 1/20, Batch 44/313, Loss: 0.7224
# Epoch 1/20, Batch 45/313, Loss: 0.6859
# Epoch 1/20, Batch 46/313, Loss: 0.6830
# Epoch 1/20, Batch 47/313, Loss: 0.6746
# Epoch 1/20, Batch 48/313, Loss: 0.7278
# Epoch 1/20, Batch 49/313, Loss: 0.7063
# Epoch 1/20, Batch 50/313, Loss: 0.7085
# Epoch 1/20, Batch 51/313, Loss: 0.7380
# Epoch 1/20, Batch 52/313, Loss: 0.7315
# Epoch 1/20, Batch 53/313, Loss: 0.7250
# Epoch 1/20, Batch 54/313, Loss: 0.7550
# Epoch 1/20, Batch 55/313, Loss: 0.7072
# Epoch 1/20, Batch 56/313, Loss: 0.7255
# Epoch 1/20, Batch 57/313, Loss: 0.6908
# Epoch 1/20, Batch 58/313, Loss: 0.7037
# Epoch 1/20, Batch 59/313, Loss: 0.6808
# Epoch 1/20, Batch 60/313, Loss: 0.7064
# Epoch 1/20, Batch 61/313, Loss: 0.7201
# Epoch 1/20, Batch 62/313, Loss: 0.7248
# Epoch 1/20, Batch 63/313, Loss: 0.6966
# Epoch 1/20, Batch 64/313, Loss: 0.6898
# Epoch 1/20, Batch 65/313, Loss: 0.7015
# Epoch 1/20, Batch 66/313, Loss: 0.6745
# Epoch 1/20, Batch 67/313, Loss: 0.7117
# Epoch 1/20, Batch 68/313, Loss: 0.7128
# Epoch 1/20, Batch 69/313, Loss: 0.7071
# Epoch 1/20, Batch 70/313, Loss: 0.6947
# Epoch 1/20, Batch 71/313, Loss: 0.7120
# Epoch 1/20, Batch 72/313, Loss: 0.7504
# Epoch 1/20, Batch 73/313, Loss: 0.7171
# Epoch 1/20, Batch 74/313, Loss: 0.7238
# Epoch 1/20, Batch 75/313, Loss: 0.7258
# Epoch 1/20, Batch 76/313, Loss: 0.7027
# Epoch 1/20, Batch 77/313, Loss: 0.6857
# Epoch 1/20, Batch 78/313, Loss: 0.7182
# Epoch 1/20, Batch 79/313, Loss: 0.7234
# Epoch 1/20, Batch 80/313, Loss: 0.6841
# Epoch 1/20, Batch 81/313, Loss: 0.7151
# Epoch 1/20, Batch 82/313, Loss: 0.7102
# Epoch 1/20, Batch 83/313, Loss: 0.7111
# Epoch 1/20, Batch 84/313, Loss: 0.7010
# Epoch 1/20, Batch 85/313, Loss: 0.7103
# Epoch 1/20, Batch 86/313, Loss: 0.6728
# Epoch 1/20, Batch 87/313, Loss: 0.6674
# Epoch 1/20, Batch 88/313, Loss: 0.7333
# Epoch 1/20, Batch 89/313, Loss: 0.7237
# Epoch 1/20, Batch 90/313, Loss: 0.6978
# Epoch 1/20, Batch 91/313, Loss: 0.7499
# Epoch 1/20, Batch 92/313, Loss: 0.7052
# Epoch 1/20, Batch 93/313, Loss: 0.7098
# Epoch 1/20, Batch 94/313, Loss: 0.7042
# Epoch 1/20, Batch 95/313, Loss: 0.7126
# Epoch 1/20, Batch 96/313, Loss: 0.6971
# Epoch 1/20, Batch 97/313, Loss: 0.7137
# Epoch 1/20, Batch 98/313, Loss: 0.7197
# Epoch 1/20, Batch 99/313, Loss: 0.6947
# Epoch 1/20, Batch 100/313, Loss: 0.7041
# Epoch 1/20, Batch 101/313, Loss: 0.7123
# Epoch 1/20, Batch 102/313, Loss: 0.6914
# Epoch 1/20, Batch 103/313, Loss: 0.7012
# Epoch 1/20, Batch 104/313, Loss: 0.7226
# Epoch 1/20, Batch 105/313, Loss: 0.6933
# Epoch 1/20, Batch 106/313, Loss: 0.7315
# Epoch 1/20, Batch 107/313, Loss: 0.7044
# Epoch 1/20, Batch 108/313, Loss: 0.6960
# Epoch 1/20, Batch 109/313, Loss: 0.7069
# Epoch 1/20, Batch 110/313, Loss: 0.6811
# Epoch 1/20, Batch 111/313, Loss: 0.7060
# Epoch 1/20, Batch 112/313, Loss: 0.6914
# Epoch 1/20, Batch 113/313, Loss: 0.6899
# Epoch 1/20, Batch 114/313, Loss: 0.7204
# Epoch 1/20, Batch 115/313, Loss: 0.7062
# Epoch 1/20, Batch 116/313, Loss: 0.7439
# Epoch 1/20, Batch 117/313, Loss: 0.7332
# Epoch 1/20, Batch 118/313, Loss: 0.6978
# Epoch 1/20, Batch 119/313, Loss: 0.7175
# Epoch 1/20, Batch 120/313, Loss: 0.6817
# Epoch 1/20, Batch 121/313, Loss: 0.7121
# Epoch 1/20, Batch 122/313, Loss: 0.7021
# Epoch 1/20, Batch 123/313, Loss: 0.7102
# Epoch 1/20, Batch 124/313, Loss: 0.6912
# Epoch 1/20, Batch 125/313, Loss: 0.6829
# Epoch 1/20, Batch 126/313, Loss: 0.7068
# Epoch 1/20, Batch 127/313, Loss: 0.6675
# Epoch 1/20, Batch 128/313, Loss: 0.7055
# Epoch 1/20, Batch 129/313, Loss: 0.6959
# Epoch 1/20, Batch 130/313, Loss: 0.6907
# Epoch 1/20, Batch 131/313, Loss: 0.6869
# Epoch 1/20, Batch 132/313, Loss: 0.6884
# Epoch 1/20, Batch 133/313, Loss: 0.7378
# Epoch 1/20, Batch 134/313, Loss: 0.6850
# Epoch 1/20, Batch 135/313, Loss: 0.6966
# Epoch 1/20, Batch 136/313, Loss: 0.6755
# Epoch 1/20, Batch 137/313, Loss: 0.6944
# Epoch 1/20, Batch 138/313, Loss: 0.7159
# Epoch 1/20, Batch 139/313, Loss: 0.7317
# Epoch 1/20, Batch 140/313, Loss: 0.6958
# Epoch 1/20, Batch 141/313, Loss: 0.7063
# Epoch 1/20, Batch 142/313, Loss: 0.6778
# Epoch 1/20, Batch 143/313, Loss: 0.7100
# Epoch 1/20, Batch 144/313, Loss: 0.6669
# Epoch 1/20, Batch 145/313, Loss: 0.7072
# Epoch 1/20, Batch 146/313, Loss: 0.7070
# Epoch 1/20, Batch 147/313, Loss: 0.7051
# Epoch 1/20, Batch 148/313, Loss: 0.6916
# Epoch 1/20, Batch 149/313, Loss: 0.7138
# Epoch 1/20, Batch 150/313, Loss: 0.6998
# Epoch 1/20, Batch 151/313, Loss: 0.7171
# Epoch 1/20, Batch 152/313, Loss: 0.7012
# Epoch 1/20, Batch 153/313, Loss: 0.6943
# Epoch 1/20, Batch 154/313, Loss: 0.7186
# Epoch 1/20, Batch 155/313, Loss: 0.7041
# Epoch 1/20, Batch 156/313, Loss: 0.6885
# Epoch 1/20, Batch 157/313, Loss: 0.7630
# Epoch 1/20, Batch 158/313, Loss: 0.7192
# Epoch 1/20, Batch 159/313, Loss: 0.7138
# Epoch 1/20, Batch 160/313, Loss: 0.7109
# Epoch 1/20, Batch 161/313, Loss: 0.6918
# Epoch 1/20, Batch 162/313, Loss: 0.6961
# Epoch 1/20, Batch 163/313, Loss: 0.7314
# Epoch 1/20, Batch 164/313, Loss: 0.7399
# Epoch 1/20, Batch 165/313, Loss: 0.6966
# Epoch 1/20, Batch 166/313, Loss: 0.7230
# Epoch 1/20, Batch 167/313, Loss: 0.7093
# Epoch 1/20, Batch 168/313, Loss: 0.7055
# Epoch 1/20, Batch 169/313, Loss: 0.6965
# Epoch 1/20, Batch 170/313, Loss: 0.7197
# Epoch 1/20, Batch 171/313, Loss: 0.6826
# Epoch 1/20, Batch 172/313, Loss: 0.6972
# Epoch 1/20, Batch 173/313, Loss: 0.6761
# Epoch 1/20, Batch 174/313, Loss: 0.6971
# Epoch 1/20, Batch 175/313, Loss: 0.6803
# Epoch 1/20, Batch 176/313, Loss: 0.7058
# Epoch 1/20, Batch 177/313, Loss: 0.6652
# Epoch 1/20, Batch 178/313, Loss: 0.7123
# Epoch 1/20, Batch 179/313, Loss: 0.7247
# Epoch 1/20, Batch 180/313, Loss: 0.7577
# Epoch 1/20, Batch 181/313, Loss: 0.6903
# Epoch 1/20, Batch 182/313, Loss: 0.7242
# Epoch 1/20, Batch 183/313, Loss: 0.7043
# Epoch 1/20, Batch 184/313, Loss: 0.7054
# Epoch 1/20, Batch 185/313, Loss: 0.7038
# Epoch 1/20, Batch 186/313, Loss: 0.7032
# Epoch 1/20, Batch 187/313, Loss: 0.6966
# Epoch 1/20, Batch 188/313, Loss: 0.6950
# Epoch 1/20, Batch 189/313, Loss: 0.6914
# Epoch 1/20, Batch 190/313, Loss: 0.7136
# Epoch 1/20, Batch 191/313, Loss: 0.6894
# Epoch 1/20, Batch 192/313, Loss: 0.6953
# Epoch 1/20, Batch 193/313, Loss: 0.7013
# Epoch 1/20, Batch 194/313, Loss: 0.6934
# Epoch 1/20, Batch 195/313, Loss: 0.7109
# Epoch 1/20, Batch 196/313, Loss: 0.7247
# Epoch 1/20, Batch 197/313, Loss: 0.6946
# Epoch 1/20, Batch 198/313, Loss: 0.6879
# Epoch 1/20, Batch 199/313, Loss: 0.6753
# Epoch 1/20, Batch 200/313, Loss: 0.6622
# Epoch 1/20, Batch 201/313, Loss: 0.7310
# Epoch 1/20, Batch 202/313, Loss: 0.7471
# Epoch 1/20, Batch 203/313, Loss: 0.6958
# Epoch 1/20, Batch 204/313, Loss: 0.6618
# Epoch 1/20, Batch 205/313, Loss: 0.7094
# Epoch 1/20, Batch 206/313, Loss: 0.6925
# Epoch 1/20, Batch 207/313, Loss: 0.7073
# Epoch 1/20, Batch 208/313, Loss: 0.6903
# Epoch 1/20, Batch 209/313, Loss: 0.7118
# Epoch 1/20, Batch 210/313, Loss: 0.7008
# Epoch 1/20, Batch 211/313, Loss: 0.6822
# Epoch 1/20, Batch 212/313, Loss: 0.7143
# Epoch 1/20, Batch 213/313, Loss: 0.6898
# Epoch 1/20, Batch 214/313, Loss: 0.6903
# Epoch 1/20, Batch 215/313, Loss: 0.6958
# Epoch 1/20, Batch 216/313, Loss: 0.6847
# Epoch 1/20, Batch 217/313, Loss: 0.7067
# Epoch 1/20, Batch 218/313, Loss: 0.7160
# Epoch 1/20, Batch 219/313, Loss: 0.6986
# Epoch 1/20, Batch 220/313, Loss: 0.7015
# Epoch 1/20, Batch 221/313, Loss: 0.6818
# Epoch 1/20, Batch 222/313, Loss: 0.7040
# Epoch 1/20, Batch 223/313, Loss: 0.6876
# Epoch 1/20, Batch 224/313, Loss: 0.7008
# Epoch 1/20, Batch 225/313, Loss: 0.6849
# Epoch 1/20, Batch 226/313, Loss: 0.7100
# Epoch 1/20, Batch 227/313, Loss: 0.7015
# Epoch 1/20, Batch 228/313, Loss: 0.6816
# Epoch 1/20, Batch 229/313, Loss: 0.6822
# Epoch 1/20, Batch 230/313, Loss: 0.7119
# Epoch 1/20, Batch 231/313, Loss: 0.6922
# Epoch 1/20, Batch 232/313, Loss: 0.6996
# Epoch 1/20, Batch 233/313, Loss: 0.7045
# Epoch 1/20, Batch 234/313, Loss: 0.7015
# Epoch 1/20, Batch 235/313, Loss: 0.6954
# Epoch 1/20, Batch 236/313, Loss: 0.6987
# Epoch 1/20, Batch 237/313, Loss: 0.6886
# Epoch 1/20, Batch 238/313, Loss: 0.6756
# Epoch 1/20, Batch 239/313, Loss: 0.6966
# Epoch 1/20, Batch 240/313, Loss: 0.7039
# Epoch 1/20, Batch 241/313, Loss: 0.6979
# Epoch 1/20, Batch 242/313, Loss: 0.6840
# Epoch 1/20, Batch 243/313, Loss: 0.7071
# Epoch 1/20, Batch 244/313, Loss: 0.6939
# Epoch 1/20, Batch 245/313, Loss: 0.7083
# Epoch 1/20, Batch 246/313, Loss: 0.7039
# Epoch 1/20, Batch 247/313, Loss: 0.6870
# Epoch 1/20, Batch 248/313, Loss: 0.7019
# Epoch 1/20, Batch 249/313, Loss: 0.6995
# Epoch 1/20, Batch 250/313, Loss: 0.7051
# Epoch 1/20, Batch 251/313, Loss: 0.7150
# Epoch 1/20, Batch 252/313, Loss: 0.7145
# Epoch 1/20, Batch 253/313, Loss: 0.7281
# Epoch 1/20, Batch 254/313, Loss: 0.6910
# Epoch 1/20, Batch 255/313, Loss: 0.6820
# Epoch 1/20, Batch 256/313, Loss: 0.6828
# Epoch 1/20, Batch 257/313, Loss: 0.7072
# Epoch 1/20, Batch 258/313, Loss: 0.6851
# Epoch 1/20, Batch 259/313, Loss: 0.6900
# Epoch 1/20, Batch 260/313, Loss: 0.7008
# Epoch 1/20, Batch 261/313, Loss: 0.6845
# Epoch 1/20, Batch 262/313, Loss: 0.6905
# Epoch 1/20, Batch 263/313, Loss: 0.6793
# Epoch 1/20, Batch 264/313, Loss: 0.6899
# Epoch 1/20, Batch 265/313, Loss: 0.6900
# Epoch 1/20, Batch 266/313, Loss: 0.7026
# Epoch 1/20, Batch 267/313, Loss: 0.6736
# Epoch 1/20, Batch 268/313, Loss: 0.6919
# Epoch 1/20, Batch 269/313, Loss: 0.7258
# Epoch 1/20, Batch 270/313, Loss: 0.7363
# Epoch 1/20, Batch 271/313, Loss: 0.6946
# Epoch 1/20, Batch 272/313, Loss: 0.6971
# Epoch 1/20, Batch 273/313, Loss: 0.7040
# Epoch 1/20, Batch 274/313, Loss: 0.6884
# Epoch 1/20, Batch 275/313, Loss: 0.6867
# Epoch 1/20, Batch 276/313, Loss: 0.7103
# Epoch 1/20, Batch 277/313, Loss: 0.7159
# Epoch 1/20, Batch 278/313, Loss: 0.6773
# Epoch 1/20, Batch 279/313, Loss: 0.7114
# Epoch 1/20, Batch 280/313, Loss: 0.6801
# Epoch 1/20, Batch 281/313, Loss: 0.7178
# Epoch 1/20, Batch 282/313, Loss: 0.7046
# Epoch 1/20, Batch 283/313, Loss: 0.6909
# Epoch 1/20, Batch 284/313, Loss: 0.6891
# Epoch 1/20, Batch 285/313, Loss: 0.6979
# Epoch 1/20, Batch 286/313, Loss: 0.6743
# Epoch 1/20, Batch 287/313, Loss: 0.6912
# Epoch 1/20, Batch 288/313, Loss: 0.7405
# Epoch 1/20, Batch 289/313, Loss: 0.7233
# Epoch 1/20, Batch 290/313, Loss: 0.7137
# Epoch 1/20, Batch 291/313, Loss: 0.7026
# Epoch 1/20, Batch 292/313, Loss: 0.6985
# Epoch 1/20, Batch 293/313, Loss: 0.6788
# Epoch 1/20, Batch 294/313, Loss: 0.7024
# Epoch 1/20, Batch 295/313, Loss: 0.7064
# Epoch 1/20, Batch 296/313, Loss: 0.6891
# Epoch 1/20, Batch 297/313, Loss: 0.6832
# Epoch 1/20, Batch 298/313, Loss: 0.6863
# Epoch 1/20, Batch 299/313, Loss: 0.7418
# Epoch 1/20, Batch 300/313, Loss: 0.6979
# Epoch 1/20, Batch 301/313, Loss: 0.6921
# Epoch 1/20, Batch 302/313, Loss: 0.6885
# Epoch 1/20, Batch 303/313, Loss: 0.7054
# Epoch 1/20, Batch 304/313, Loss: 0.6880
# Epoch 1/20, Batch 305/313, Loss: 0.7014
# Epoch 1/20, Batch 306/313, Loss: 0.6961
# Epoch 1/20, Batch 307/313, Loss: 0.6939
# Epoch 1/20, Batch 308/313, Loss: 0.6892
# Epoch 1/20, Batch 309/313, Loss: 0.6926
# Epoch 1/20, Batch 310/313, Loss: 0.6963
# Epoch 1/20, Batch 311/313, Loss: 0.6825
# Epoch 1/20, Batch 312/313, Loss: 0.7010
# Epoch 1/20, Batch 313/313, Loss: 0.6882
#
# Epoch 1/20 finished, Avg Loss: 0.7049
# Epoch 1/20, Validation Batch 1/79
# Epoch 1/20, Validation Batch 2/79
# Epoch 1/20, Validation Batch 3/79
# Epoch 1/20, Validation Batch 4/79
# Epoch 1/20, Validation Batch 5/79
# Epoch 1/20, Validation Batch 6/79
# Epoch 1/20, Validation Batch 7/79
# Epoch 1/20, Validation Batch 8/79
# Epoch 1/20, Validation Batch 9/79
# Epoch 1/20, Validation Batch 10/79
# Epoch 1/20, Validation Batch 11/79
# Epoch 1/20, Validation Batch 12/79
# Epoch 1/20, Validation Batch 13/79
# Epoch 1/20, Validation Batch 14/79
# Epoch 1/20, Validation Batch 15/79
# Epoch 1/20, Validation Batch 16/79
# Epoch 1/20, Validation Batch 17/79
# Epoch 1/20, Validation Batch 18/79
# Epoch 1/20, Validation Batch 19/79
# Epoch 1/20, Validation Batch 20/79
# Epoch 1/20, Validation Batch 21/79
# Epoch 1/20, Validation Batch 22/79
# Epoch 1/20, Validation Batch 23/79
# Epoch 1/20, Validation Batch 24/79
# Epoch 1/20, Validation Batch 25/79
# Epoch 1/20, Validation Batch 26/79
# Epoch 1/20, Validation Batch 27/79
# Epoch 1/20, Validation Batch 28/79
# Epoch 1/20, Validation Batch 29/79
# Epoch 1/20, Validation Batch 30/79
# Epoch 1/20, Validation Batch 31/79
# Epoch 1/20, Validation Batch 32/79
# Epoch 1/20, Validation Batch 33/79
# Epoch 1/20, Validation Batch 34/79
# Epoch 1/20, Validation Batch 35/79
# Epoch 1/20, Validation Batch 36/79
# Epoch 1/20, Validation Batch 37/79
# Epoch 1/20, Validation Batch 38/79
# Epoch 1/20, Validation Batch 39/79
# Epoch 1/20, Validation Batch 40/79
# Epoch 1/20, Validation Batch 41/79
# Epoch 1/20, Validation Batch 42/79
# Epoch 1/20, Validation Batch 43/79
# Epoch 1/20, Validation Batch 44/79
# Epoch 1/20, Validation Batch 45/79
# Epoch 1/20, Validation Batch 46/79
# Epoch 1/20, Validation Batch 47/79
# Epoch 1/20, Validation Batch 48/79
# Epoch 1/20, Validation Batch 49/79
# Epoch 1/20, Validation Batch 50/79
# Epoch 1/20, Validation Batch 51/79
# Epoch 1/20, Validation Batch 52/79
# Epoch 1/20, Validation Batch 53/79
# Epoch 1/20, Validation Batch 54/79
# Epoch 1/20, Validation Batch 55/79
# Epoch 1/20, Validation Batch 56/79
# Epoch 1/20, Validation Batch 57/79
# Epoch 1/20, Validation Batch 58/79
# Epoch 1/20, Validation Batch 59/79
# Epoch 1/20, Validation Batch 60/79
# Epoch 1/20, Validation Batch 61/79
# Epoch 1/20, Validation Batch 62/79
# Epoch 1/20, Validation Batch 63/79
# Epoch 1/20, Validation Batch 64/79
# Epoch 1/20, Validation Batch 65/79
# Epoch 1/20, Validation Batch 66/79
# Epoch 1/20, Validation Batch 67/79
# Epoch 1/20, Validation Batch 68/79
# Epoch 1/20, Validation Batch 69/79
# Epoch 1/20, Validation Batch 70/79
# Epoch 1/20, Validation Batch 71/79
# Epoch 1/20, Validation Batch 72/79
# Epoch 1/20, Validation Batch 73/79
# Epoch 1/20, Validation Batch 74/79
# Epoch 1/20, Validation Batch 75/79
# Epoch 1/20, Validation Batch 76/79
# Epoch 1/20, Validation Batch 77/79
# Epoch 1/20, Validation Batch 78/79
# Epoch 1/20, Validation Batch 79/79
#
# Validation Accuracy: 0.4970
# New best model saved with Validation Accuracy: 0.4970
# Unfreezing BERT embeddings for fine-tuning...
# Epoch 2/20, Batch 1/313, Loss: 0.6987
# Epoch 2/20, Batch 2/313, Loss: 0.7027
# Epoch 2/20, Batch 3/313, Loss: 0.6958
# Epoch 2/20, Batch 4/313, Loss: 0.7019
# Epoch 2/20, Batch 5/313, Loss: 0.6890
# Epoch 2/20, Batch 6/313, Loss: 0.6928
# Epoch 2/20, Batch 7/313, Loss: 0.6917
# Epoch 2/20, Batch 8/313, Loss: 0.7041
# Epoch 2/20, Batch 9/313, Loss: 0.7088
# Epoch 2/20, Batch 10/313, Loss: 0.6840
# Epoch 2/20, Batch 11/313, Loss: 0.7003
# Epoch 2/20, Batch 12/313, Loss: 0.6972
# Epoch 2/20, Batch 13/313, Loss: 0.6892
# Epoch 2/20, Batch 14/313, Loss: 0.6853
# Epoch 2/20, Batch 15/313, Loss: 0.7039
# Epoch 2/20, Batch 16/313, Loss: 0.6868
# Epoch 2/20, Batch 17/313, Loss: 0.7047
# Epoch 2/20, Batch 18/313, Loss: 0.6861
# Epoch 2/20, Batch 19/313, Loss: 0.7061
# Epoch 2/20, Batch 20/313, Loss: 0.7075
# Epoch 2/20, Batch 21/313, Loss: 0.6894
# Epoch 2/20, Batch 22/313, Loss: 0.6974
# Epoch 2/20, Batch 23/313, Loss: 0.6944
# Epoch 2/20, Batch 24/313, Loss: 0.7044
# Epoch 2/20, Batch 25/313, Loss: 0.6809
# Epoch 2/20, Batch 26/313, Loss: 0.7013
# Epoch 2/20, Batch 27/313, Loss: 0.7115
# Epoch 2/20, Batch 28/313, Loss: 0.6981
# Epoch 2/20, Batch 29/313, Loss: 0.6726
# Epoch 2/20, Batch 30/313, Loss: 0.6875
# Epoch 2/20, Batch 31/313, Loss: 0.6990
# Epoch 2/20, Batch 32/313, Loss: 0.6741
# Epoch 2/20, Batch 33/313, Loss: 0.7311
# Epoch 2/20, Batch 34/313, Loss: 0.7269
# Epoch 2/20, Batch 35/313, Loss: 0.7371
# Epoch 2/20, Batch 36/313, Loss: 0.7118
# Epoch 2/20, Batch 37/313, Loss: 0.6919
# Epoch 2/20, Batch 38/313, Loss: 0.7224
# Epoch 2/20, Batch 39/313, Loss: 0.7258
# Epoch 2/20, Batch 40/313, Loss: 0.6829
# Epoch 2/20, Batch 41/313, Loss: 0.7151
# Epoch 2/20, Batch 42/313, Loss: 0.7016
# Epoch 2/20, Batch 43/313, Loss: 0.6945
# Epoch 2/20, Batch 44/313, Loss: 0.6729
# Epoch 2/20, Batch 45/313, Loss: 0.7038
# Epoch 2/20, Batch 46/313, Loss: 0.6999
# Epoch 2/20, Batch 47/313, Loss: 0.6851
# Epoch 2/20, Batch 48/313, Loss: 0.6975
# Epoch 2/20, Batch 49/313, Loss: 0.6978
# Epoch 2/20, Batch 50/313, Loss: 0.6921
# Epoch 2/20, Batch 51/313, Loss: 0.6909
# Epoch 2/20, Batch 52/313, Loss: 0.6751
# Epoch 2/20, Batch 53/313, Loss: 0.6922
# Epoch 2/20, Batch 54/313, Loss: 0.7021
# Epoch 2/20, Batch 55/313, Loss: 0.7112
# Epoch 2/20, Batch 56/313, Loss: 0.7156
# Epoch 2/20, Batch 57/313, Loss: 0.6739
# Epoch 2/20, Batch 58/313, Loss: 0.7154
# Epoch 2/20, Batch 59/313, Loss: 0.6928
# Epoch 2/20, Batch 60/313, Loss: 0.6842
# Epoch 2/20, Batch 61/313, Loss: 0.6786
# Epoch 2/20, Batch 62/313, Loss: 0.6831
# Epoch 2/20, Batch 63/313, Loss: 0.6895
# Epoch 2/20, Batch 64/313, Loss: 0.7079
# Epoch 2/20, Batch 65/313, Loss: 0.7005
# Epoch 2/20, Batch 66/313, Loss: 0.6890
# Epoch 2/20, Batch 67/313, Loss: 0.6992
# Epoch 2/20, Batch 68/313, Loss: 0.6992
# Epoch 2/20, Batch 69/313, Loss: 0.6914
# Epoch 2/20, Batch 70/313, Loss: 0.7083
# Epoch 2/20, Batch 71/313, Loss: 0.6964
# Epoch 2/20, Batch 72/313, Loss: 0.6920
# Epoch 2/20, Batch 73/313, Loss: 0.7040
# Epoch 2/20, Batch 74/313, Loss: 0.6992
# Epoch 2/20, Batch 75/313, Loss: 0.6997
# Epoch 2/20, Batch 76/313, Loss: 0.6884
# Epoch 2/20, Batch 77/313, Loss: 0.6928
# Epoch 2/20, Batch 78/313, Loss: 0.6914
# Epoch 2/20, Batch 79/313, Loss: 0.6935
# Epoch 2/20, Batch 80/313, Loss: 0.7065
# Epoch 2/20, Batch 81/313, Loss: 0.7089
# Epoch 2/20, Batch 82/313, Loss: 0.6823
# Epoch 2/20, Batch 83/313, Loss: 0.7210
# Epoch 2/20, Batch 84/313, Loss: 0.6904
# Epoch 2/20, Batch 85/313, Loss: 0.7031
# Epoch 2/20, Batch 86/313, Loss: 0.6848
# Epoch 2/20, Batch 87/313, Loss: 0.7039
# Epoch 2/20, Batch 88/313, Loss: 0.6893
# Epoch 2/20, Batch 89/313, Loss: 0.6949
# Epoch 2/20, Batch 90/313, Loss: 0.6915
# Epoch 2/20, Batch 91/313, Loss: 0.6970
# Epoch 2/20, Batch 92/313, Loss: 0.7170
# Epoch 2/20, Batch 93/313, Loss: 0.7251
# Epoch 2/20, Batch 94/313, Loss: 0.6814
# Epoch 2/20, Batch 95/313, Loss: 0.7045
# Epoch 2/20, Batch 96/313, Loss: 0.7014
# Epoch 2/20, Batch 97/313, Loss: 0.6783
# Epoch 2/20, Batch 98/313, Loss: 0.7008
# Epoch 2/20, Batch 99/313, Loss: 0.6994
# Epoch 2/20, Batch 100/313, Loss: 0.7043
# Epoch 2/20, Batch 101/313, Loss: 0.6876
# Epoch 2/20, Batch 102/313, Loss: 0.7175
# Epoch 2/20, Batch 103/313, Loss: 0.6983
# Epoch 2/20, Batch 104/313, Loss: 0.7005
# Epoch 2/20, Batch 105/313, Loss: 0.6965
# Epoch 2/20, Batch 106/313, Loss: 0.7091
# Epoch 2/20, Batch 107/313, Loss: 0.6897
# Epoch 2/20, Batch 108/313, Loss: 0.6980
# Epoch 2/20, Batch 109/313, Loss: 0.7057
# Epoch 2/20, Batch 110/313, Loss: 0.6783
# Epoch 2/20, Batch 111/313, Loss: 0.6912
# Epoch 2/20, Batch 112/313, Loss: 0.6806
# Epoch 2/20, Batch 113/313, Loss: 0.7321
# Epoch 2/20, Batch 114/313, Loss: 0.6809
# Epoch 2/20, Batch 115/313, Loss: 0.7195
# Epoch 2/20, Batch 116/313, Loss: 0.7020
# Epoch 2/20, Batch 117/313, Loss: 0.7004
# Epoch 2/20, Batch 118/313, Loss: 0.6963
# Epoch 2/20, Batch 119/313, Loss: 0.7015
# Epoch 2/20, Batch 120/313, Loss: 0.7086
# Epoch 2/20, Batch 121/313, Loss: 0.6946
# Epoch 2/20, Batch 122/313, Loss: 0.6945
# Epoch 2/20, Batch 123/313, Loss: 0.6930
# Epoch 2/20, Batch 124/313, Loss: 0.7028
# Epoch 2/20, Batch 125/313, Loss: 0.7044
# Epoch 2/20, Batch 126/313, Loss: 0.6896
# Epoch 2/20, Batch 127/313, Loss: 0.6785
# Epoch 2/20, Batch 128/313, Loss: 0.7139
# Epoch 2/20, Batch 129/313, Loss: 0.7071
# Epoch 2/20, Batch 130/313, Loss: 0.6895
# Epoch 2/20, Batch 131/313, Loss: 0.7018
# Epoch 2/20, Batch 132/313, Loss: 0.6865
# Epoch 2/20, Batch 133/313, Loss: 0.7002
# Epoch 2/20, Batch 134/313, Loss: 0.6831
# Epoch 2/20, Batch 135/313, Loss: 0.6930
# Epoch 2/20, Batch 136/313, Loss: 0.6991
# Epoch 2/20, Batch 137/313, Loss: 0.6820
# Epoch 2/20, Batch 138/313, Loss: 0.6910
# Epoch 2/20, Batch 139/313, Loss: 0.7000
# Epoch 2/20, Batch 140/313, Loss: 0.6788
# Epoch 2/20, Batch 141/313, Loss: 0.6764
# Epoch 2/20, Batch 142/313, Loss: 0.7044
# Epoch 2/20, Batch 143/313, Loss: 0.6957
# Epoch 2/20, Batch 144/313, Loss: 0.6866
# Epoch 2/20, Batch 145/313, Loss: 0.7223
# Epoch 2/20, Batch 146/313, Loss: 0.7215
# Epoch 2/20, Batch 147/313, Loss: 0.6978
# Epoch 2/20, Batch 148/313, Loss: 0.6945
# Epoch 2/20, Batch 149/313, Loss: 0.6946
# Epoch 2/20, Batch 150/313, Loss: 0.6990
# Epoch 2/20, Batch 151/313, Loss: 0.6878
# Epoch 2/20, Batch 152/313, Loss: 0.6847
# Epoch 2/20, Batch 153/313, Loss: 0.7068
# Epoch 2/20, Batch 154/313, Loss: 0.7050
# Epoch 2/20, Batch 155/313, Loss: 0.6796
# Epoch 2/20, Batch 156/313, Loss: 0.7017
# Epoch 2/20, Batch 157/313, Loss: 0.7061
# Epoch 2/20, Batch 158/313, Loss: 0.6897
# Epoch 2/20, Batch 159/313, Loss: 0.6822
# Epoch 2/20, Batch 160/313, Loss: 0.6894
# Epoch 2/20, Batch 161/313, Loss: 0.6797
# Epoch 2/20, Batch 162/313, Loss: 0.7130
# Epoch 2/20, Batch 163/313, Loss: 0.6812
# Epoch 2/20, Batch 164/313, Loss: 0.7094
# Epoch 2/20, Batch 165/313, Loss: 0.6884
# Epoch 2/20, Batch 166/313, Loss: 0.6843
# Epoch 2/20, Batch 167/313, Loss: 0.7152
# Epoch 2/20, Batch 168/313, Loss: 0.6954
# Epoch 2/20, Batch 169/313, Loss: 0.6936
# Epoch 2/20, Batch 170/313, Loss: 0.6859
# Epoch 2/20, Batch 171/313, Loss: 0.6851
# Epoch 2/20, Batch 172/313, Loss: 0.6915
# Epoch 2/20, Batch 173/313, Loss: 0.7058
# Epoch 2/20, Batch 174/313, Loss: 0.7056
# Epoch 2/20, Batch 175/313, Loss: 0.6990
# Epoch 2/20, Batch 176/313, Loss: 0.6844
# Epoch 2/20, Batch 177/313, Loss: 0.7030
# Epoch 2/20, Batch 178/313, Loss: 0.7064
# Epoch 2/20, Batch 179/313, Loss: 0.6872
# Epoch 2/20, Batch 180/313, Loss: 0.7006
# Epoch 2/20, Batch 181/313, Loss: 0.6825
# Epoch 2/20, Batch 182/313, Loss: 0.6876
# Epoch 2/20, Batch 183/313, Loss: 0.6976
# Epoch 2/20, Batch 184/313, Loss: 0.7066
# Epoch 2/20, Batch 185/313, Loss: 0.6981
# Epoch 2/20, Batch 186/313, Loss: 0.6982
# Epoch 2/20, Batch 187/313, Loss: 0.6938
# Epoch 2/20, Batch 188/313, Loss: 0.6919
# Epoch 2/20, Batch 189/313, Loss: 0.7012
# Epoch 2/20, Batch 190/313, Loss: 0.6956
# Epoch 2/20, Batch 191/313, Loss: 0.6948
# Epoch 2/20, Batch 192/313, Loss: 0.6888
# Epoch 2/20, Batch 193/313, Loss: 0.6942
# Epoch 2/20, Batch 194/313, Loss: 0.7208
# Epoch 2/20, Batch 195/313, Loss: 0.6933
# Epoch 2/20, Batch 196/313, Loss: 0.6935
# Epoch 2/20, Batch 197/313, Loss: 0.6911
# Epoch 2/20, Batch 198/313, Loss: 0.7000
# Epoch 2/20, Batch 199/313, Loss: 0.6977
# Epoch 2/20, Batch 200/313, Loss: 0.7026
# Epoch 2/20, Batch 201/313, Loss: 0.6929
# Epoch 2/20, Batch 202/313, Loss: 0.7057
# Epoch 2/20, Batch 203/313, Loss: 0.6965
# Epoch 2/20, Batch 204/313, Loss: 0.7022
# Epoch 2/20, Batch 205/313, Loss: 0.6916
# Epoch 2/20, Batch 206/313, Loss: 0.7096
# Epoch 2/20, Batch 207/313, Loss: 0.6885
# Epoch 2/20, Batch 208/313, Loss: 0.6792
# Epoch 2/20, Batch 209/313, Loss: 0.6799
# Epoch 2/20, Batch 210/313, Loss: 0.7008
# Epoch 2/20, Batch 211/313, Loss: 0.7018
# Epoch 2/20, Batch 212/313, Loss: 0.6767
# Epoch 2/20, Batch 213/313, Loss: 0.7086
# Epoch 2/20, Batch 214/313, Loss: 0.6905
# Epoch 2/20, Batch 215/313, Loss: 0.7119
# Epoch 2/20, Batch 216/313, Loss: 0.6928
# Epoch 2/20, Batch 217/313, Loss: 0.6927
# Epoch 2/20, Batch 218/313, Loss: 0.6961
# Epoch 2/20, Batch 219/313, Loss: 0.6917
# Epoch 2/20, Batch 220/313, Loss: 0.6932
# Epoch 2/20, Batch 221/313, Loss: 0.7039
# Epoch 2/20, Batch 222/313, Loss: 0.7082
# Epoch 2/20, Batch 223/313, Loss: 0.6893
# Epoch 2/20, Batch 224/313, Loss: 0.6874
# Epoch 2/20, Batch 225/313, Loss: 0.6988
# Epoch 2/20, Batch 226/313, Loss: 0.6979
# Epoch 2/20, Batch 227/313, Loss: 0.7016
# Epoch 2/20, Batch 228/313, Loss: 0.6945
# Epoch 2/20, Batch 229/313, Loss: 0.7060
# Epoch 2/20, Batch 230/313, Loss: 0.6864
# Epoch 2/20, Batch 231/313, Loss: 0.7035
# Epoch 2/20, Batch 232/313, Loss: 0.6992
# Epoch 2/20, Batch 233/313, Loss: 0.6890
# Epoch 2/20, Batch 234/313, Loss: 0.7041
# Epoch 2/20, Batch 235/313, Loss: 0.6946
# Epoch 2/20, Batch 236/313, Loss: 0.6929
# Epoch 2/20, Batch 237/313, Loss: 0.7051
# Epoch 2/20, Batch 238/313, Loss: 0.6835
# Epoch 2/20, Batch 239/313, Loss: 0.7154
# Epoch 2/20, Batch 240/313, Loss: 0.7000
# Epoch 2/20, Batch 241/313, Loss: 0.6850
# Epoch 2/20, Batch 242/313, Loss: 0.7066
# Epoch 2/20, Batch 243/313, Loss: 0.7196
# Epoch 2/20, Batch 244/313, Loss: 0.7324
# Epoch 2/20, Batch 245/313, Loss: 0.7162
# Epoch 2/20, Batch 246/313, Loss: 0.7074
# Epoch 2/20, Batch 247/313, Loss: 0.6862
# Epoch 2/20, Batch 248/313, Loss: 0.7082
# Epoch 2/20, Batch 249/313, Loss: 0.7226
# Epoch 2/20, Batch 250/313, Loss: 0.7435
# Epoch 2/20, Batch 251/313, Loss: 0.6909
# Epoch 2/20, Batch 252/313, Loss: 0.6942
# Epoch 2/20, Batch 253/313, Loss: 0.7010
# Epoch 2/20, Batch 254/313, Loss: 0.6850
# Epoch 2/20, Batch 255/313, Loss: 0.6941
# Epoch 2/20, Batch 256/313, Loss: 0.7034
# Epoch 2/20, Batch 257/313, Loss: 0.7011
# Epoch 2/20, Batch 258/313, Loss: 0.6981
# Epoch 2/20, Batch 259/313, Loss: 0.6913
# Epoch 2/20, Batch 260/313, Loss: 0.6888
# Epoch 2/20, Batch 261/313, Loss: 0.7053
# Epoch 2/20, Batch 262/313, Loss: 0.7298
# Epoch 2/20, Batch 263/313, Loss: 0.7217
# Epoch 2/20, Batch 264/313, Loss: 0.6878
# Epoch 2/20, Batch 265/313, Loss: 0.6971
# Epoch 2/20, Batch 266/313, Loss: 0.6944
# Epoch 2/20, Batch 267/313, Loss: 0.7008
# Epoch 2/20, Batch 268/313, Loss: 0.6951
# Epoch 2/20, Batch 269/313, Loss: 0.7036
# Epoch 2/20, Batch 270/313, Loss: 0.6961
# Epoch 2/20, Batch 271/313, Loss: 0.6969
# Epoch 2/20, Batch 272/313, Loss: 0.6990
# Epoch 2/20, Batch 273/313, Loss: 0.7066
# Epoch 2/20, Batch 274/313, Loss: 0.6923
# Epoch 2/20, Batch 275/313, Loss: 0.6925
# Epoch 2/20, Batch 276/313, Loss: 0.6934
# Epoch 2/20, Batch 277/313, Loss: 0.6990
# Epoch 2/20, Batch 278/313, Loss: 0.6945
# Epoch 2/20, Batch 279/313, Loss: 0.6829
# Epoch 2/20, Batch 280/313, Loss: 0.6829
# Epoch 2/20, Batch 281/313, Loss: 0.6920
# Epoch 2/20, Batch 282/313, Loss: 0.6863
# Epoch 2/20, Batch 283/313, Loss: 0.7031
# Epoch 2/20, Batch 284/313, Loss: 0.6958
# Epoch 2/20, Batch 285/313, Loss: 0.6920
# Epoch 2/20, Batch 286/313, Loss: 0.7095
# Epoch 2/20, Batch 287/313, Loss: 0.6925
# Epoch 2/20, Batch 288/313, Loss: 0.6891
# Epoch 2/20, Batch 289/313, Loss: 0.6958
# Epoch 2/20, Batch 290/313, Loss: 0.6876
# Epoch 2/20, Batch 291/313, Loss: 0.6806
# Epoch 2/20, Batch 292/313, Loss: 0.6942
# Epoch 2/20, Batch 293/313, Loss: 0.6997
# Epoch 2/20, Batch 294/313, Loss: 0.7026
# Epoch 2/20, Batch 295/313, Loss: 0.7007
# Epoch 2/20, Batch 296/313, Loss: 0.6950
# Epoch 2/20, Batch 297/313, Loss: 0.6826
# Epoch 2/20, Batch 298/313, Loss: 0.6870
# Epoch 2/20, Batch 299/313, Loss: 0.7037
# Epoch 2/20, Batch 300/313, Loss: 0.7068
# Epoch 2/20, Batch 301/313, Loss: 0.6984
# Epoch 2/20, Batch 302/313, Loss: 0.6939
# Epoch 2/20, Batch 303/313, Loss: 0.6926
# Epoch 2/20, Batch 304/313, Loss: 0.6964
# Epoch 2/20, Batch 305/313, Loss: 0.6944
# Epoch 2/20, Batch 306/313, Loss: 0.6950
# Epoch 2/20, Batch 307/313, Loss: 0.7001
# Epoch 2/20, Batch 308/313, Loss: 0.7040
# Epoch 2/20, Batch 309/313, Loss: 0.7086
# Epoch 2/20, Batch 310/313, Loss: 0.7012
# Epoch 2/20, Batch 311/313, Loss: 0.6941
# Epoch 2/20, Batch 312/313, Loss: 0.6930
# Epoch 2/20, Batch 313/313, Loss: 0.6868
#
# Epoch 2/20 finished, Avg Loss: 0.6974
# Epoch 2/20, Validation Batch 1/79
# Epoch 2/20, Validation Batch 2/79
# Epoch 2/20, Validation Batch 3/79
# Epoch 2/20, Validation Batch 4/79
# Epoch 2/20, Validation Batch 5/79
# Epoch 2/20, Validation Batch 6/79
# Epoch 2/20, Validation Batch 7/79
# Epoch 2/20, Validation Batch 8/79
# Epoch 2/20, Validation Batch 9/79
# Epoch 2/20, Validation Batch 10/79
# Epoch 2/20, Validation Batch 11/79
# Epoch 2/20, Validation Batch 12/79
# Epoch 2/20, Validation Batch 13/79
# Epoch 2/20, Validation Batch 14/79
# Epoch 2/20, Validation Batch 15/79
# Epoch 2/20, Validation Batch 16/79
# Epoch 2/20, Validation Batch 17/79
# Epoch 2/20, Validation Batch 18/79
# Epoch 2/20, Validation Batch 19/79
# Epoch 2/20, Validation Batch 20/79
# Epoch 2/20, Validation Batch 21/79
# Epoch 2/20, Validation Batch 22/79
# Epoch 2/20, Validation Batch 23/79
# Epoch 2/20, Validation Batch 24/79
# Epoch 2/20, Validation Batch 25/79
# Epoch 2/20, Validation Batch 26/79
# Epoch 2/20, Validation Batch 27/79
# Epoch 2/20, Validation Batch 28/79
# Epoch 2/20, Validation Batch 29/79
# Epoch 2/20, Validation Batch 30/79
# Epoch 2/20, Validation Batch 31/79
# Epoch 2/20, Validation Batch 32/79
# Epoch 2/20, Validation Batch 33/79
# Epoch 2/20, Validation Batch 34/79
# Epoch 2/20, Validation Batch 35/79
# Epoch 2/20, Validation Batch 36/79
# Epoch 2/20, Validation Batch 37/79
# Epoch 2/20, Validation Batch 38/79
# Epoch 2/20, Validation Batch 39/79
# Epoch 2/20, Validation Batch 40/79
# Epoch 2/20, Validation Batch 41/79
# Epoch 2/20, Validation Batch 42/79
# Epoch 2/20, Validation Batch 43/79
# Epoch 2/20, Validation Batch 44/79
# Epoch 2/20, Validation Batch 45/79
# Epoch 2/20, Validation Batch 46/79
# Epoch 2/20, Validation Batch 47/79
# Epoch 2/20, Validation Batch 48/79
# Epoch 2/20, Validation Batch 49/79
# Epoch 2/20, Validation Batch 50/79
# Epoch 2/20, Validation Batch 51/79
# Epoch 2/20, Validation Batch 52/79
# Epoch 2/20, Validation Batch 53/79
# Epoch 2/20, Validation Batch 54/79
# Epoch 2/20, Validation Batch 55/79
# Epoch 2/20, Validation Batch 56/79
# Epoch 2/20, Validation Batch 57/79
# Epoch 2/20, Validation Batch 58/79
# Epoch 2/20, Validation Batch 59/79
# Epoch 2/20, Validation Batch 60/79
# Epoch 2/20, Validation Batch 61/79
# Epoch 2/20, Validation Batch 62/79
# Epoch 2/20, Validation Batch 63/79
# Epoch 2/20, Validation Batch 64/79
# Epoch 2/20, Validation Batch 65/79
# Epoch 2/20, Validation Batch 66/79
# Epoch 2/20, Validation Batch 67/79
# Epoch 2/20, Validation Batch 68/79
# Epoch 2/20, Validation Batch 69/79
# Epoch 2/20, Validation Batch 70/79
# Epoch 2/20, Validation Batch 71/79
# Epoch 2/20, Validation Batch 72/79
# Epoch 2/20, Validation Batch 73/79
# Epoch 2/20, Validation Batch 74/79
# Epoch 2/20, Validation Batch 75/79
# Epoch 2/20, Validation Batch 76/79
# Epoch 2/20, Validation Batch 77/79
# Epoch 2/20, Validation Batch 78/79
# Epoch 2/20, Validation Batch 79/79
#
# Validation Accuracy: 0.4970
# Epoch 3/20, Batch 1/313, Loss: 0.6913
# Epoch 3/20, Batch 2/313, Loss: 0.6898
# Epoch 3/20, Batch 3/313, Loss: 0.7084
# Epoch 3/20, Batch 4/313, Loss: 0.7126
# Epoch 3/20, Batch 5/313, Loss: 0.7092
# Epoch 3/20, Batch 6/313, Loss: 0.6927
# Epoch 3/20, Batch 7/313, Loss: 0.6964
# Epoch 3/20, Batch 8/313, Loss: 0.6934
# Epoch 3/20, Batch 9/313, Loss: 0.6925
# Epoch 3/20, Batch 10/313, Loss: 0.6858
# Epoch 3/20, Batch 11/313, Loss: 0.7077
# Epoch 3/20, Batch 12/313, Loss: 0.6939
# Epoch 3/20, Batch 13/313, Loss: 0.6873
# Epoch 3/20, Batch 14/313, Loss: 0.6874
# Epoch 3/20, Batch 15/313, Loss: 0.7076
# Epoch 3/20, Batch 16/313, Loss: 0.6899
# Epoch 3/20, Batch 17/313, Loss: 0.6822
# Epoch 3/20, Batch 18/313, Loss: 0.6969
# Epoch 3/20, Batch 19/313, Loss: 0.6921
# Epoch 3/20, Batch 20/313, Loss: 0.6898
# Epoch 3/20, Batch 21/313, Loss: 0.6881
# Epoch 3/20, Batch 22/313, Loss: 0.6935
# Epoch 3/20, Batch 23/313, Loss: 0.6913
# Epoch 3/20, Batch 24/313, Loss: 0.7097
# Epoch 3/20, Batch 25/313, Loss: 0.7041
# Epoch 3/20, Batch 26/313, Loss: 0.7039
# Epoch 3/20, Batch 27/313, Loss: 0.6983
# Epoch 3/20, Batch 28/313, Loss: 0.6833
# Epoch 3/20, Batch 29/313, Loss: 0.6870
# Epoch 3/20, Batch 30/313, Loss: 0.6825
# Epoch 3/20, Batch 31/313, Loss: 0.6936
# Epoch 3/20, Batch 32/313, Loss: 0.7025
# Epoch 3/20, Batch 33/313, Loss: 0.6975
# Epoch 3/20, Batch 34/313, Loss: 0.7263
# Epoch 3/20, Batch 35/313, Loss: 0.7295
# Epoch 3/20, Batch 36/313, Loss: 0.6827
# Epoch 3/20, Batch 37/313, Loss: 0.6861
# Epoch 3/20, Batch 38/313, Loss: 0.6956
# Epoch 3/20, Batch 39/313, Loss: 0.6940
# Epoch 3/20, Batch 40/313, Loss: 0.6905
# Epoch 3/20, Batch 41/313, Loss: 0.7011
# Epoch 3/20, Batch 42/313, Loss: 0.6928
# Epoch 3/20, Batch 43/313, Loss: 0.6989
# Epoch 3/20, Batch 44/313, Loss: 0.6949
# Epoch 3/20, Batch 45/313, Loss: 0.6859
# Epoch 3/20, Batch 46/313, Loss: 0.6882
# Epoch 3/20, Batch 47/313, Loss: 0.6862
# Epoch 3/20, Batch 48/313, Loss: 0.6941
# Epoch 3/20, Batch 49/313, Loss: 0.6821
# Epoch 3/20, Batch 50/313, Loss: 0.6991
# Epoch 3/20, Batch 51/313, Loss: 0.7288
# Epoch 3/20, Batch 52/313, Loss: 0.7196
# Epoch 3/20, Batch 53/313, Loss: 0.6947
# Epoch 3/20, Batch 54/313, Loss: 0.6913
# Epoch 3/20, Batch 55/313, Loss: 0.6847
# Epoch 3/20, Batch 56/313, Loss: 0.6922
# Epoch 3/20, Batch 57/313, Loss: 0.7015
# Epoch 3/20, Batch 58/313, Loss: 0.7072
# Epoch 3/20, Batch 59/313, Loss: 0.6899
# Epoch 3/20, Batch 60/313, Loss: 0.7001
# Epoch 3/20, Batch 61/313, Loss: 0.6951
# Epoch 3/20, Batch 62/313, Loss: 0.6972
# Epoch 3/20, Batch 63/313, Loss: 0.6949
# Epoch 3/20, Batch 64/313, Loss: 0.6872
# Epoch 3/20, Batch 65/313, Loss: 0.6789
# Epoch 3/20, Batch 66/313, Loss: 0.7007
# Epoch 3/20, Batch 67/313, Loss: 0.7154
# Epoch 3/20, Batch 68/313, Loss: 0.6978
# Epoch 3/20, Batch 69/313, Loss: 0.7108
# Epoch 3/20, Batch 70/313, Loss: 0.7037
# Epoch 3/20, Batch 71/313, Loss: 0.7055
# Epoch 3/20, Batch 72/313, Loss: 0.7155
# Epoch 3/20, Batch 73/313, Loss: 0.7014
# Epoch 3/20, Batch 74/313, Loss: 0.7034
# Epoch 3/20, Batch 75/313, Loss: 0.6986
# Epoch 3/20, Batch 76/313, Loss: 0.6811
# Epoch 3/20, Batch 77/313, Loss: 0.6946
# Epoch 3/20, Batch 78/313, Loss: 0.6971
# Epoch 3/20, Batch 79/313, Loss: 0.7010
# Epoch 3/20, Batch 80/313, Loss: 0.7190
# Epoch 3/20, Batch 81/313, Loss: 0.6947
# Epoch 3/20, Batch 82/313, Loss: 0.6832
# Epoch 3/20, Batch 83/313, Loss: 0.7110
# Epoch 3/20, Batch 84/313, Loss: 0.6777
# Epoch 3/20, Batch 85/313, Loss: 0.6729
# Epoch 3/20, Batch 86/313, Loss: 0.7039
# Epoch 3/20, Batch 87/313, Loss: 0.7141
# Epoch 3/20, Batch 88/313, Loss: 0.7042
# Epoch 3/20, Batch 89/313, Loss: 0.6975
# Epoch 3/20, Batch 90/313, Loss: 0.6894
# Epoch 3/20, Batch 91/313, Loss: 0.6973
# Epoch 3/20, Batch 92/313, Loss: 0.6880
# Epoch 3/20, Batch 93/313, Loss: 0.6830
# Epoch 3/20, Batch 94/313, Loss: 0.6932
# Epoch 3/20, Batch 95/313, Loss: 0.6894
# Epoch 3/20, Batch 96/313, Loss: 0.6960
# Epoch 3/20, Batch 97/313, Loss: 0.6883
# Epoch 3/20, Batch 98/313, Loss: 0.6892
# Epoch 3/20, Batch 99/313, Loss: 0.6949
# Epoch 3/20, Batch 100/313, Loss: 0.6936
# Epoch 3/20, Batch 101/313, Loss: 0.7017
# Epoch 3/20, Batch 102/313, Loss: 0.6871
# Epoch 3/20, Batch 103/313, Loss: 0.6861
# Epoch 3/20, Batch 104/313, Loss: 0.6879
# Epoch 3/20, Batch 105/313, Loss: 0.6990
# Epoch 3/20, Batch 106/313, Loss: 0.7077
# Epoch 3/20, Batch 107/313, Loss: 0.6924
# Epoch 3/20, Batch 108/313, Loss: 0.7014
# Epoch 3/20, Batch 109/313, Loss: 0.6965
# Epoch 3/20, Batch 110/313, Loss: 0.6879
# Epoch 3/20, Batch 111/313, Loss: 0.7005
# Epoch 3/20, Batch 112/313, Loss: 0.6930
# Epoch 3/20, Batch 113/313, Loss: 0.6957
# Epoch 3/20, Batch 114/313, Loss: 0.7052
# Epoch 3/20, Batch 115/313, Loss: 0.6955
# Epoch 3/20, Batch 116/313, Loss: 0.6867
# Epoch 3/20, Batch 117/313, Loss: 0.6945
# Epoch 3/20, Batch 118/313, Loss: 0.6910
# Epoch 3/20, Batch 119/313, Loss: 0.6752
# Epoch 3/20, Batch 120/313, Loss: 0.7050
# Epoch 3/20, Batch 121/313, Loss: 0.6754
# Epoch 3/20, Batch 122/313, Loss: 0.6663
# Epoch 3/20, Batch 123/313, Loss: 0.7074
# Epoch 3/20, Batch 124/313, Loss: 0.7115
# Epoch 3/20, Batch 125/313, Loss: 0.6960
# Epoch 3/20, Batch 126/313, Loss: 0.6509
# Epoch 3/20, Batch 127/313, Loss: 0.7157
# Epoch 3/20, Batch 128/313, Loss: 0.7087
# Epoch 3/20, Batch 129/313, Loss: 0.6978
# Epoch 3/20, Batch 130/313, Loss: 0.6743
# Epoch 3/20, Batch 131/313, Loss: 0.6966
# Epoch 3/20, Batch 132/313, Loss: 0.6961
# Epoch 3/20, Batch 133/313, Loss: 0.7068
# Epoch 3/20, Batch 134/313, Loss: 0.6951
# Epoch 3/20, Batch 135/313, Loss: 0.6933
# Epoch 3/20, Batch 136/313, Loss: 0.6981
# Epoch 3/20, Batch 137/313, Loss: 0.6829
# Epoch 3/20, Batch 138/313, Loss: 0.7151
# Epoch 3/20, Batch 139/313, Loss: 0.6832
# Epoch 3/20, Batch 140/313, Loss: 0.6982
# Epoch 3/20, Batch 141/313, Loss: 0.6860
# Epoch 3/20, Batch 142/313, Loss: 0.7044
# Epoch 3/20, Batch 143/313, Loss: 0.6950
# Epoch 3/20, Batch 144/313, Loss: 0.6720
# Epoch 3/20, Batch 145/313, Loss: 0.7142
# Epoch 3/20, Batch 146/313, Loss: 0.6926
# Epoch 3/20, Batch 147/313, Loss: 0.7017
# Epoch 3/20, Batch 148/313, Loss: 0.6683
# Epoch 3/20, Batch 149/313, Loss: 0.6926
# Epoch 3/20, Batch 150/313, Loss: 0.7082
# Epoch 3/20, Batch 151/313, Loss: 0.6977
# Epoch 3/20, Batch 152/313, Loss: 0.6956
# Epoch 3/20, Batch 153/313, Loss: 0.6826
# Epoch 3/20, Batch 154/313, Loss: 0.6943
# Epoch 3/20, Batch 155/313, Loss: 0.7013
# Epoch 3/20, Batch 156/313, Loss: 0.6968
# Epoch 3/20, Batch 157/313, Loss: 0.7012
# Epoch 3/20, Batch 158/313, Loss: 0.6952
# Epoch 3/20, Batch 159/313, Loss: 0.6928
# Epoch 3/20, Batch 160/313, Loss: 0.6918
# Epoch 3/20, Batch 161/313, Loss: 0.6989
# Epoch 3/20, Batch 162/313, Loss: 0.6886
# Epoch 3/20, Batch 163/313, Loss: 0.7019
# Epoch 3/20, Batch 164/313, Loss: 0.6926
# Epoch 3/20, Batch 165/313, Loss: 0.6929
# Epoch 3/20, Batch 166/313, Loss: 0.7027
# Epoch 3/20, Batch 167/313, Loss: 0.7008
# Epoch 3/20, Batch 168/313, Loss: 0.6900
# Epoch 3/20, Batch 169/313, Loss: 0.6987
# Epoch 3/20, Batch 170/313, Loss: 0.6936
# Epoch 3/20, Batch 171/313, Loss: 0.6946
# Epoch 3/20, Batch 172/313, Loss: 0.7010
# Epoch 3/20, Batch 173/313, Loss: 0.6908
# Epoch 3/20, Batch 174/313, Loss: 0.6898
# Epoch 3/20, Batch 175/313, Loss: 0.6891
# Epoch 3/20, Batch 176/313, Loss: 0.6959
# Epoch 3/20, Batch 177/313, Loss: 0.6893
# Epoch 3/20, Batch 178/313, Loss: 0.6911
# Epoch 3/20, Batch 179/313, Loss: 0.7041
# Epoch 3/20, Batch 180/313, Loss: 0.6811
# Epoch 3/20, Batch 181/313, Loss: 0.6938
# Epoch 3/20, Batch 182/313, Loss: 0.7014
# Epoch 3/20, Batch 183/313, Loss: 0.7100
# Epoch 3/20, Batch 184/313, Loss: 0.6913
# Epoch 3/20, Batch 185/313, Loss: 0.7011
# Epoch 3/20, Batch 186/313, Loss: 0.6823
# Epoch 3/20, Batch 187/313, Loss: 0.6921
# Epoch 3/20, Batch 188/313, Loss: 0.7070
# Epoch 3/20, Batch 189/313, Loss: 0.7041
# Epoch 3/20, Batch 190/313, Loss: 0.6933
# Epoch 3/20, Batch 191/313, Loss: 0.6979
# Epoch 3/20, Batch 192/313, Loss: 0.6953
# Epoch 3/20, Batch 193/313, Loss: 0.6897
# Epoch 3/20, Batch 194/313, Loss: 0.6764
# Epoch 3/20, Batch 195/313, Loss: 0.7220
# Epoch 3/20, Batch 196/313, Loss: 0.6713
# Epoch 3/20, Batch 197/313, Loss: 0.6860
# Epoch 3/20, Batch 198/313, Loss: 0.7031
# Epoch 3/20, Batch 199/313, Loss: 0.6807
# Epoch 3/20, Batch 200/313, Loss: 0.6691
# Epoch 3/20, Batch 201/313, Loss: 0.6969
# Epoch 3/20, Batch 202/313, Loss: 0.6862
# Epoch 3/20, Batch 203/313, Loss: 0.6887
# Epoch 3/20, Batch 204/313, Loss: 0.6974
# Epoch 3/20, Batch 205/313, Loss: 0.7182
# Epoch 3/20, Batch 206/313, Loss: 0.7062
# Epoch 3/20, Batch 207/313, Loss: 0.6914
# Epoch 3/20, Batch 208/313, Loss: 0.6855
# Epoch 3/20, Batch 209/313, Loss: 0.6970
# Epoch 3/20, Batch 210/313, Loss: 0.6896
# Epoch 3/20, Batch 211/313, Loss: 0.6919
# Epoch 3/20, Batch 212/313, Loss: 0.7039
# Epoch 3/20, Batch 213/313, Loss: 0.6929
# Epoch 3/20, Batch 214/313, Loss: 0.6905
# Epoch 3/20, Batch 215/313, Loss: 0.6918
# Epoch 3/20, Batch 216/313, Loss: 0.6796
# Epoch 3/20, Batch 217/313, Loss: 0.7034
# Epoch 3/20, Batch 218/313, Loss: 0.6815
# Epoch 3/20, Batch 219/313, Loss: 0.7178
# Epoch 3/20, Batch 220/313, Loss: 0.6909
# Epoch 3/20, Batch 221/313, Loss: 0.6925
# Epoch 3/20, Batch 222/313, Loss: 0.7073
# Epoch 3/20, Batch 223/313, Loss: 0.6778
# Epoch 3/20, Batch 224/313, Loss: 0.6989
# Epoch 3/20, Batch 225/313, Loss: 0.6998
# Epoch 3/20, Batch 226/313, Loss: 0.6991
# Epoch 3/20, Batch 227/313, Loss: 0.6886
# Epoch 3/20, Batch 228/313, Loss: 0.6959
# Epoch 3/20, Batch 229/313, Loss: 0.6985
# Epoch 3/20, Batch 230/313, Loss: 0.6875
# Epoch 3/20, Batch 231/313, Loss: 0.7047
# Epoch 3/20, Batch 232/313, Loss: 0.6971
# Epoch 3/20, Batch 233/313, Loss: 0.6984
# Epoch 3/20, Batch 234/313, Loss: 0.6846
# Epoch 3/20, Batch 235/313, Loss: 0.6951
# Epoch 3/20, Batch 236/313, Loss: 0.6721
# Epoch 3/20, Batch 237/313, Loss: 0.6941
# Epoch 3/20, Batch 238/313, Loss: 0.6810
# Epoch 3/20, Batch 239/313, Loss: 0.6836
# Epoch 3/20, Batch 240/313, Loss: 0.7011
# Epoch 3/20, Batch 241/313, Loss: 0.6914
# Epoch 3/20, Batch 242/313, Loss: 0.7022
# Epoch 3/20, Batch 243/313, Loss: 0.6847
# Epoch 3/20, Batch 244/313, Loss: 0.6829
# Epoch 3/20, Batch 245/313, Loss: 0.6866
# Epoch 3/20, Batch 246/313, Loss: 0.6928
# Epoch 3/20, Batch 247/313, Loss: 0.7083
# Epoch 3/20, Batch 248/313, Loss: 0.6934
# Epoch 3/20, Batch 249/313, Loss: 0.6949
# Epoch 3/20, Batch 250/313, Loss: 0.6982
# Epoch 3/20, Batch 251/313, Loss: 0.6857
# Epoch 3/20, Batch 252/313, Loss: 0.6949
# Epoch 3/20, Batch 253/313, Loss: 0.6959
# Epoch 3/20, Batch 254/313, Loss: 0.6873
# Epoch 3/20, Batch 255/313, Loss: 0.6952
# Epoch 3/20, Batch 256/313, Loss: 0.6864
# Epoch 3/20, Batch 257/313, Loss: 0.6952
# Epoch 3/20, Batch 258/313, Loss: 0.6878
# Epoch 3/20, Batch 259/313, Loss: 0.7078
# Epoch 3/20, Batch 260/313, Loss: 0.6833
# Epoch 3/20, Batch 261/313, Loss: 0.6872
# Epoch 3/20, Batch 262/313, Loss: 0.6999
# Epoch 3/20, Batch 263/313, Loss: 0.6806
# Epoch 3/20, Batch 264/313, Loss: 0.7001
# Epoch 3/20, Batch 265/313, Loss: 0.7040
# Epoch 3/20, Batch 266/313, Loss: 0.7055
# Epoch 3/20, Batch 267/313, Loss: 0.6932
# Epoch 3/20, Batch 268/313, Loss: 0.6901
# Epoch 3/20, Batch 269/313, Loss: 0.6940
# Epoch 3/20, Batch 270/313, Loss: 0.6938
# Epoch 3/20, Batch 271/313, Loss: 0.6903
# Epoch 3/20, Batch 272/313, Loss: 0.6905
# Epoch 3/20, Batch 273/313, Loss: 0.6957
# Epoch 3/20, Batch 274/313, Loss: 0.7019
# Epoch 3/20, Batch 275/313, Loss: 0.6887
# Epoch 3/20, Batch 276/313, Loss: 0.6904
# Epoch 3/20, Batch 277/313, Loss: 0.6959
# Epoch 3/20, Batch 278/313, Loss: 0.6951
# Epoch 3/20, Batch 279/313, Loss: 0.6928
# Epoch 3/20, Batch 280/313, Loss: 0.7068
# Epoch 3/20, Batch 281/313, Loss: 0.7004
# Epoch 3/20, Batch 282/313, Loss: 0.7107
# Epoch 3/20, Batch 283/313, Loss: 0.6913
# Epoch 3/20, Batch 284/313, Loss: 0.6801
# Epoch 3/20, Batch 285/313, Loss: 0.6913
# Epoch 3/20, Batch 286/313, Loss: 0.6950
# Epoch 3/20, Batch 287/313, Loss: 0.6770
# Epoch 3/20, Batch 288/313, Loss: 0.6958
# Epoch 3/20, Batch 289/313, Loss: 0.6860
# Epoch 3/20, Batch 290/313, Loss: 0.6990
# Epoch 3/20, Batch 291/313, Loss: 0.6935
# Epoch 3/20, Batch 292/313, Loss: 0.6994
# Epoch 3/20, Batch 293/313, Loss: 0.6921
# Epoch 3/20, Batch 294/313, Loss: 0.6933
# Epoch 3/20, Batch 295/313, Loss: 0.7006
# Epoch 3/20, Batch 296/313, Loss: 0.6987
# Epoch 3/20, Batch 297/313, Loss: 0.6924
# Epoch 3/20, Batch 298/313, Loss: 0.6894
# Epoch 3/20, Batch 299/313, Loss: 0.6996
# Epoch 3/20, Batch 300/313, Loss: 0.7210
# Epoch 3/20, Batch 301/313, Loss: 0.7257
# Epoch 3/20, Batch 302/313, Loss: 0.6979
# Epoch 3/20, Batch 303/313, Loss: 0.6985
# Epoch 3/20, Batch 304/313, Loss: 0.6927
# Epoch 3/20, Batch 305/313, Loss: 0.6952
# Epoch 3/20, Batch 306/313, Loss: 0.6911
# Epoch 3/20, Batch 307/313, Loss: 0.6857
# Epoch 3/20, Batch 308/313, Loss: 0.6876
# Epoch 3/20, Batch 309/313, Loss: 0.6915
# Epoch 3/20, Batch 310/313, Loss: 0.6916
# Epoch 3/20, Batch 311/313, Loss: 0.6710
# Epoch 3/20, Batch 312/313, Loss: 0.6997
# Epoch 3/20, Batch 313/313, Loss: 0.7361
#
# Epoch 3/20 finished, Avg Loss: 0.6950
# Epoch 3/20, Validation Batch 1/79
# Epoch 3/20, Validation Batch 2/79
# Epoch 3/20, Validation Batch 3/79
# Epoch 3/20, Validation Batch 4/79
# Epoch 3/20, Validation Batch 5/79
# Epoch 3/20, Validation Batch 6/79
# Epoch 3/20, Validation Batch 7/79
# Epoch 3/20, Validation Batch 8/79
# Epoch 3/20, Validation Batch 9/79
# Epoch 3/20, Validation Batch 10/79
# Epoch 3/20, Validation Batch 11/79
# Epoch 3/20, Validation Batch 12/79
# Epoch 3/20, Validation Batch 13/79
# Epoch 3/20, Validation Batch 14/79
# Epoch 3/20, Validation Batch 15/79
# Epoch 3/20, Validation Batch 16/79
# Epoch 3/20, Validation Batch 17/79
# Epoch 3/20, Validation Batch 18/79
# Epoch 3/20, Validation Batch 19/79
# Epoch 3/20, Validation Batch 20/79
# Epoch 3/20, Validation Batch 21/79
# Epoch 3/20, Validation Batch 22/79
# Epoch 3/20, Validation Batch 23/79
# Epoch 3/20, Validation Batch 24/79
# Epoch 3/20, Validation Batch 25/79
# Epoch 3/20, Validation Batch 26/79
# Epoch 3/20, Validation Batch 27/79
# Epoch 3/20, Validation Batch 28/79
# Epoch 3/20, Validation Batch 29/79
# Epoch 3/20, Validation Batch 30/79
# Epoch 3/20, Validation Batch 31/79
# Epoch 3/20, Validation Batch 32/79
# Epoch 3/20, Validation Batch 33/79
# Epoch 3/20, Validation Batch 34/79
# Epoch 3/20, Validation Batch 35/79
# Epoch 3/20, Validation Batch 36/79
# Epoch 3/20, Validation Batch 37/79
# Epoch 3/20, Validation Batch 38/79
# Epoch 3/20, Validation Batch 39/79
# Epoch 3/20, Validation Batch 40/79
# Epoch 3/20, Validation Batch 41/79
# Epoch 3/20, Validation Batch 42/79
# Epoch 3/20, Validation Batch 43/79
# Epoch 3/20, Validation Batch 44/79
# Epoch 3/20, Validation Batch 45/79
# Epoch 3/20, Validation Batch 46/79
# Epoch 3/20, Validation Batch 47/79
# Epoch 3/20, Validation Batch 48/79
# Epoch 3/20, Validation Batch 49/79
# Epoch 3/20, Validation Batch 50/79
# Epoch 3/20, Validation Batch 51/79
# Epoch 3/20, Validation Batch 52/79
# Epoch 3/20, Validation Batch 53/79
# Epoch 3/20, Validation Batch 54/79
# Epoch 3/20, Validation Batch 55/79
# Epoch 3/20, Validation Batch 56/79
# Epoch 3/20, Validation Batch 57/79
# Epoch 3/20, Validation Batch 58/79
# Epoch 3/20, Validation Batch 59/79
# Epoch 3/20, Validation Batch 60/79
# Epoch 3/20, Validation Batch 61/79
# Epoch 3/20, Validation Batch 62/79
# Epoch 3/20, Validation Batch 63/79
# Epoch 3/20, Validation Batch 64/79
# Epoch 3/20, Validation Batch 65/79
# Epoch 3/20, Validation Batch 66/79
# Epoch 3/20, Validation Batch 67/79
# Epoch 3/20, Validation Batch 68/79
# Epoch 3/20, Validation Batch 69/79
# Epoch 3/20, Validation Batch 70/79
# Epoch 3/20, Validation Batch 71/79
# Epoch 3/20, Validation Batch 72/79
# Epoch 3/20, Validation Batch 73/79
# Epoch 3/20, Validation Batch 74/79
# Epoch 3/20, Validation Batch 75/79
# Epoch 3/20, Validation Batch 76/79
# Epoch 3/20, Validation Batch 77/79
# Epoch 3/20, Validation Batch 78/79
# Epoch 3/20, Validation Batch 79/79
#
# Validation Accuracy: 0.4970
# Epoch 4/20, Batch 1/313, Loss: 0.7076
# Epoch 4/20, Batch 2/313, Loss: 0.6852
# Epoch 4/20, Batch 3/313, Loss: 0.7002
# Epoch 4/20, Batch 4/313, Loss: 0.6813
# Epoch 4/20, Batch 5/313, Loss: 0.7263
# Epoch 4/20, Batch 6/313, Loss: 0.6885
# Epoch 4/20, Batch 7/313, Loss: 0.6879
# Epoch 4/20, Batch 8/313, Loss: 0.6892
# Epoch 4/20, Batch 9/313, Loss: 0.6941
# Epoch 4/20, Batch 10/313, Loss: 0.6786
# Epoch 4/20, Batch 11/313, Loss: 0.6937
# Epoch 4/20, Batch 12/313, Loss: 0.7197
# Epoch 4/20, Batch 13/313, Loss: 0.7017
# Epoch 4/20, Batch 14/313, Loss: 0.6952
# Epoch 4/20, Batch 15/313, Loss: 0.6939
# Epoch 4/20, Batch 16/313, Loss: 0.6895
# Epoch 4/20, Batch 17/313, Loss: 0.6888
# Epoch 4/20, Batch 18/313, Loss: 0.7021
# Epoch 4/20, Batch 19/313, Loss: 0.6964
# Epoch 4/20, Batch 20/313, Loss: 0.6962
# Epoch 4/20, Batch 21/313, Loss: 0.6820
# Epoch 4/20, Batch 22/313, Loss: 0.7005
# Epoch 4/20, Batch 23/313, Loss: 0.6774
# Epoch 4/20, Batch 24/313, Loss: 0.6749
# Epoch 4/20, Batch 25/313, Loss: 0.6999
# Epoch 4/20, Batch 26/313, Loss: 0.7261
# Epoch 4/20, Batch 27/313, Loss: 0.6967
# Epoch 4/20, Batch 28/313, Loss: 0.6906
# Epoch 4/20, Batch 29/313, Loss: 0.7225
# Epoch 4/20, Batch 30/313, Loss: 0.7090
# Epoch 4/20, Batch 31/313, Loss: 0.7147
# Epoch 4/20, Batch 32/313, Loss: 0.6927
# Epoch 4/20, Batch 33/313, Loss: 0.7015
# Epoch 4/20, Batch 34/313, Loss: 0.6950
# Epoch 4/20, Batch 35/313, Loss: 0.6907
# Epoch 4/20, Batch 36/313, Loss: 0.6997
# Epoch 4/20, Batch 37/313, Loss: 0.7011
# Epoch 4/20, Batch 38/313, Loss: 0.6747
# Epoch 4/20, Batch 39/313, Loss: 0.6830
# Epoch 4/20, Batch 40/313, Loss: 0.7067
# Epoch 4/20, Batch 41/313, Loss: 0.6863
# Epoch 4/20, Batch 42/313, Loss: 0.7229
# Epoch 4/20, Batch 43/313, Loss: 0.7279
# Epoch 4/20, Batch 44/313, Loss: 0.6843
# Epoch 4/20, Batch 45/313, Loss: 0.6880
# Epoch 4/20, Batch 46/313, Loss: 0.6899
# Epoch 4/20, Batch 47/313, Loss: 0.6944
# Epoch 4/20, Batch 48/313, Loss: 0.6904
# Epoch 4/20, Batch 49/313, Loss: 0.6850
# Epoch 4/20, Batch 50/313, Loss: 0.6813
# Epoch 4/20, Batch 51/313, Loss: 0.6989
# Epoch 4/20, Batch 52/313, Loss: 0.6856
# Epoch 4/20, Batch 53/313, Loss: 0.6877
# Epoch 4/20, Batch 54/313, Loss: 0.6968
# Epoch 4/20, Batch 55/313, Loss: 0.7015
# ...
# Epoch 19/20, Validation Batch 71/79
# Epoch 19/20, Validation Batch 72/79
# Epoch 19/20, Validation Batch 73/79
# Epoch 19/20, Validation Batch 74/79
# Epoch 19/20, Validation Batch 75/79
# Epoch 19/20, Validation Batch 76/79
# Epoch 19/20, Validation Batch 77/79
# Epoch 19/20, Validation Batch 78/79
# Epoch 19/20, Validation Batch 79/79
#
# Validation Accuracy: 0.8724
# Epoch 20/20, Batch 1/313, Loss: 0.1820
# Epoch 20/20, Batch 2/313, Loss: 0.1462
# Epoch 20/20, Batch 3/313, Loss: 0.2269
# Epoch 20/20, Batch 4/313, Loss: 0.0785
# Epoch 20/20, Batch 5/313, Loss: 0.2087
# Epoch 20/20, Batch 6/313, Loss: 0.2516
# Epoch 20/20, Batch 7/313, Loss: 0.1422
# Epoch 20/20, Batch 8/313, Loss: 0.1200
# Epoch 20/20, Batch 9/313, Loss: 0.1610
# Epoch 20/20, Batch 10/313, Loss: 0.1283
# Epoch 20/20, Batch 11/313, Loss: 0.0676
# Epoch 20/20, Batch 12/313, Loss: 0.2482
# Epoch 20/20, Batch 13/313, Loss: 0.0806
# Epoch 20/20, Batch 14/313, Loss: 0.1380
# Epoch 20/20, Batch 15/313, Loss: 0.1476
# Epoch 20/20, Batch 16/313, Loss: 0.0653
# Epoch 20/20, Batch 17/313, Loss: 0.0987
# Epoch 20/20, Batch 18/313, Loss: 0.0677
# Epoch 20/20, Batch 19/313, Loss: 0.1098
# Epoch 20/20, Batch 20/313, Loss: 0.2125
# Epoch 20/20, Batch 21/313, Loss: 0.2471
# Epoch 20/20, Batch 22/313, Loss: 0.0981
# Epoch 20/20, Batch 23/313, Loss: 0.2217
# Epoch 20/20, Batch 24/313, Loss: 0.1319
# Epoch 20/20, Batch 25/313, Loss: 0.2563
# Epoch 20/20, Batch 26/313, Loss: 0.0700
# Epoch 20/20, Batch 27/313, Loss: 0.1678
# Epoch 20/20, Batch 28/313, Loss: 0.1966
# Epoch 20/20, Batch 29/313, Loss: 0.3202
# Epoch 20/20, Batch 30/313, Loss: 0.1459
# Epoch 20/20, Batch 31/313, Loss: 0.1851
# Epoch 20/20, Batch 32/313, Loss: 0.1912
# Epoch 20/20, Batch 33/313, Loss: 0.0912
# Epoch 20/20, Batch 34/313, Loss: 0.3188
# Epoch 20/20, Batch 35/313, Loss: 0.0912
# Epoch 20/20, Batch 36/313, Loss: 0.2371
# Epoch 20/20, Batch 37/313, Loss: 0.2561
# Epoch 20/20, Batch 38/313, Loss: 0.1616
# Epoch 20/20, Batch 39/313, Loss: 0.1488
# Epoch 20/20, Batch 40/313, Loss: 0.1474
# Epoch 20/20, Batch 41/313, Loss: 0.2325
# Epoch 20/20, Batch 42/313, Loss: 0.1290
# Epoch 20/20, Batch 43/313, Loss: 0.1845
# Epoch 20/20, Batch 44/313, Loss: 0.2121
# Epoch 20/20, Batch 45/313, Loss: 0.1530
# Epoch 20/20, Batch 46/313, Loss: 0.0851
# Epoch 20/20, Batch 47/313, Loss: 0.1653
# Epoch 20/20, Batch 48/313, Loss: 0.3125
# Epoch 20/20, Batch 49/313, Loss: 0.2169
# Epoch 20/20, Batch 50/313, Loss: 0.1636
# Epoch 20/20, Batch 51/313, Loss: 0.1293
# Epoch 20/20, Batch 52/313, Loss: 0.1642
# Epoch 20/20, Batch 53/313, Loss: 0.2053
# Epoch 20/20, Batch 54/313, Loss: 0.1650
# Epoch 20/20, Batch 55/313, Loss: 0.1730
# Epoch 20/20, Batch 56/313, Loss: 0.2306
# Epoch 20/20, Batch 57/313, Loss: 0.1504
# Epoch 20/20, Batch 58/313, Loss: 0.1888
# Epoch 20/20, Batch 59/313, Loss: 0.0963
# Epoch 20/20, Batch 60/313, Loss: 0.1615
# Epoch 20/20, Batch 61/313, Loss: 0.2084
# Epoch 20/20, Batch 62/313, Loss: 0.0516
# Epoch 20/20, Batch 63/313, Loss: 0.1391
# Epoch 20/20, Batch 64/313, Loss: 0.1521
# Epoch 20/20, Batch 65/313, Loss: 0.1802
# Epoch 20/20, Batch 66/313, Loss: 0.0977
# Epoch 20/20, Batch 67/313, Loss: 0.0951
# Epoch 20/20, Batch 68/313, Loss: 0.1133
# Epoch 20/20, Batch 69/313, Loss: 0.1595
# Epoch 20/20, Batch 70/313, Loss: 0.0959
# Epoch 20/20, Batch 71/313, Loss: 0.2380
# Epoch 20/20, Batch 72/313, Loss: 0.1322
# Epoch 20/20, Batch 73/313, Loss: 0.1175
# Epoch 20/20, Batch 74/313, Loss: 0.2268
# Epoch 20/20, Batch 75/313, Loss: 0.1868
# Epoch 20/20, Batch 76/313, Loss: 0.1936
# Epoch 20/20, Batch 77/313, Loss: 0.2189
# Epoch 20/20, Batch 78/313, Loss: 0.1283
# Epoch 20/20, Batch 79/313, Loss: 0.1362
# Epoch 20/20, Batch 80/313, Loss: 0.1749
# Epoch 20/20, Batch 81/313, Loss: 0.1948
# Epoch 20/20, Batch 82/313, Loss: 0.2278
# Epoch 20/20, Batch 83/313, Loss: 0.0768
# Epoch 20/20, Batch 84/313, Loss: 0.1527
# Epoch 20/20, Batch 85/313, Loss: 0.2310
# Epoch 20/20, Batch 86/313, Loss: 0.1689
# Epoch 20/20, Batch 87/313, Loss: 0.1598
# Epoch 20/20, Batch 88/313, Loss: 0.2086
# Epoch 20/20, Batch 89/313, Loss: 0.1186
# Epoch 20/20, Batch 90/313, Loss: 0.2304
# Epoch 20/20, Batch 91/313, Loss: 0.2101
# Epoch 20/20, Batch 92/313, Loss: 0.1763
# Epoch 20/20, Batch 93/313, Loss: 0.1029
# Epoch 20/20, Batch 94/313, Loss: 0.1233
# Epoch 20/20, Batch 95/313, Loss: 0.1497
# Epoch 20/20, Batch 96/313, Loss: 0.1489
# Epoch 20/20, Batch 97/313, Loss: 0.2051
# Epoch 20/20, Batch 98/313, Loss: 0.1507
# Epoch 20/20, Batch 99/313, Loss: 0.2184
# Epoch 20/20, Batch 100/313, Loss: 0.2631
# Epoch 20/20, Batch 101/313, Loss: 0.1126
# Epoch 20/20, Batch 102/313, Loss: 0.1651
# Epoch 20/20, Batch 103/313, Loss: 0.1889
# Epoch 20/20, Batch 104/313, Loss: 0.1920
# Epoch 20/20, Batch 105/313, Loss: 0.1566
# Epoch 20/20, Batch 106/313, Loss: 0.1164
# Epoch 20/20, Batch 107/313, Loss: 0.1089
# Epoch 20/20, Batch 108/313, Loss: 0.1125
# Epoch 20/20, Batch 109/313, Loss: 0.2828
# Epoch 20/20, Batch 110/313, Loss: 0.1872
# Epoch 20/20, Batch 111/313, Loss: 0.1871
# Epoch 20/20, Batch 112/313, Loss: 0.1661
# Epoch 20/20, Batch 113/313, Loss: 0.1442
# Epoch 20/20, Batch 114/313, Loss: 0.1899
# Epoch 20/20, Batch 115/313, Loss: 0.1591
# Epoch 20/20, Batch 116/313, Loss: 0.1629
# Epoch 20/20, Batch 117/313, Loss: 0.1200
# Epoch 20/20, Batch 118/313, Loss: 0.1662
# Epoch 20/20, Batch 119/313, Loss: 0.1369
# Epoch 20/20, Batch 120/313, Loss: 0.1749
# Epoch 20/20, Batch 121/313, Loss: 0.1047
# Epoch 20/20, Batch 122/313, Loss: 0.1819
# Epoch 20/20, Batch 123/313, Loss: 0.1430
# Epoch 20/20, Batch 124/313, Loss: 0.1185
# Epoch 20/20, Batch 125/313, Loss: 0.1714
# Epoch 20/20, Batch 126/313, Loss: 0.1229
# Epoch 20/20, Batch 127/313, Loss: 0.1597
# Epoch 20/20, Batch 128/313, Loss: 0.2063
# Epoch 20/20, Batch 129/313, Loss: 0.1653
# Epoch 20/20, Batch 130/313, Loss: 0.2546
# Epoch 20/20, Batch 131/313, Loss: 0.1647
# Epoch 20/20, Batch 132/313, Loss: 0.0834
# Epoch 20/20, Batch 133/313, Loss: 0.1460
# Epoch 20/20, Batch 134/313, Loss: 0.2392
# Epoch 20/20, Batch 135/313, Loss: 0.0541
# Epoch 20/20, Batch 136/313, Loss: 0.2118
# Epoch 20/20, Batch 137/313, Loss: 0.1723
# Epoch 20/20, Batch 138/313, Loss: 0.2020
# Epoch 20/20, Batch 139/313, Loss: 0.2219
# Epoch 20/20, Batch 140/313, Loss: 0.0893
# Epoch 20/20, Batch 141/313, Loss: 0.2067
# Epoch 20/20, Batch 142/313, Loss: 0.2387
# Epoch 20/20, Batch 143/313, Loss: 0.2372
# Epoch 20/20, Batch 144/313, Loss: 0.2252
# Epoch 20/20, Batch 145/313, Loss: 0.1000
# Epoch 20/20, Batch 146/313, Loss: 0.1049
# Epoch 20/20, Batch 147/313, Loss: 0.0753
# Epoch 20/20, Batch 148/313, Loss: 0.1510
# Epoch 20/20, Batch 149/313, Loss: 0.1784
# Epoch 20/20, Batch 150/313, Loss: 0.1543
# Epoch 20/20, Batch 151/313, Loss: 0.1397
# Epoch 20/20, Batch 152/313, Loss: 0.1634
# Epoch 20/20, Batch 153/313, Loss: 0.1662
# Epoch 20/20, Batch 154/313, Loss: 0.1964
# Epoch 20/20, Batch 155/313, Loss: 0.1767
# Epoch 20/20, Batch 156/313, Loss: 0.1291
# Epoch 20/20, Batch 157/313, Loss: 0.1280
# Epoch 20/20, Batch 158/313, Loss: 0.1031
# Epoch 20/20, Batch 159/313, Loss: 0.2396
# Epoch 20/20, Batch 160/313, Loss: 0.3109
# Epoch 20/20, Batch 161/313, Loss: 0.3576
# Epoch 20/20, Batch 162/313, Loss: 0.1697
# Epoch 20/20, Batch 163/313, Loss: 0.1083
# Epoch 20/20, Batch 164/313, Loss: 0.1693
# Epoch 20/20, Batch 165/313, Loss: 0.1798
# Epoch 20/20, Batch 166/313, Loss: 0.1914
# Epoch 20/20, Batch 167/313, Loss: 0.1480
# Epoch 20/20, Batch 168/313, Loss: 0.2197
# Epoch 20/20, Batch 169/313, Loss: 0.1366
# Epoch 20/20, Batch 170/313, Loss: 0.0806
# Epoch 20/20, Batch 171/313, Loss: 0.1076
# Epoch 20/20, Batch 172/313, Loss: 0.1132
# Epoch 20/20, Batch 173/313, Loss: 0.1320
# Epoch 20/20, Batch 174/313, Loss: 0.1321
# Epoch 20/20, Batch 175/313, Loss: 0.1995
# Epoch 20/20, Batch 176/313, Loss: 0.2919
# Epoch 20/20, Batch 177/313, Loss: 0.2014
# Epoch 20/20, Batch 178/313, Loss: 0.1227
# Epoch 20/20, Batch 179/313, Loss: 0.1666
# Epoch 20/20, Batch 180/313, Loss: 0.1440
# Epoch 20/20, Batch 181/313, Loss: 0.1258
# Epoch 20/20, Batch 182/313, Loss: 0.1402
# Epoch 20/20, Batch 183/313, Loss: 0.0926
# Epoch 20/20, Batch 184/313, Loss: 0.1070
# Epoch 20/20, Batch 185/313, Loss: 0.1621
# Epoch 20/20, Batch 186/313, Loss: 0.1609
# Epoch 20/20, Batch 187/313, Loss: 0.0977
# Epoch 20/20, Batch 188/313, Loss: 0.0958
# Epoch 20/20, Batch 189/313, Loss: 0.1793
# Epoch 20/20, Batch 190/313, Loss: 0.0746
# Epoch 20/20, Batch 191/313, Loss: 0.1347
# Epoch 20/20, Batch 192/313, Loss: 0.0986
# Epoch 20/20, Batch 193/313, Loss: 0.1403
# Epoch 20/20, Batch 194/313, Loss: 0.1813
# Epoch 20/20, Batch 195/313, Loss: 0.2188
# Epoch 20/20, Batch 196/313, Loss: 0.2183
# Epoch 20/20, Batch 197/313, Loss: 0.0700
# Epoch 20/20, Batch 198/313, Loss: 0.1472
# Epoch 20/20, Batch 199/313, Loss: 0.2320
# Epoch 20/20, Batch 200/313, Loss: 0.1165
# Epoch 20/20, Batch 201/313, Loss: 0.1670
# Epoch 20/20, Batch 202/313, Loss: 0.2424
# Epoch 20/20, Batch 203/313, Loss: 0.1219
# Epoch 20/20, Batch 204/313, Loss: 0.0569
# Epoch 20/20, Batch 205/313, Loss: 0.1838
# Epoch 20/20, Batch 206/313, Loss: 0.1489
# Epoch 20/20, Batch 207/313, Loss: 0.1256
# Epoch 20/20, Batch 208/313, Loss: 0.1384
# Epoch 20/20, Batch 209/313, Loss: 0.2120
# Epoch 20/20, Batch 210/313, Loss: 0.2057
# Epoch 20/20, Batch 211/313, Loss: 0.1121
# Epoch 20/20, Batch 212/313, Loss: 0.1134
# Epoch 20/20, Batch 213/313, Loss: 0.1523
# Epoch 20/20, Batch 214/313, Loss: 0.1445
# Epoch 20/20, Batch 215/313, Loss: 0.3076
# Epoch 20/20, Batch 216/313, Loss: 0.2624
# Epoch 20/20, Batch 217/313, Loss: 0.1161
# Epoch 20/20, Batch 218/313, Loss: 0.1993
# Epoch 20/20, Batch 219/313, Loss: 0.1231
# Epoch 20/20, Batch 220/313, Loss: 0.1002
# Epoch 20/20, Batch 221/313, Loss: 0.1075
# Epoch 20/20, Batch 222/313, Loss: 0.3086
# Epoch 20/20, Batch 223/313, Loss: 0.0659
# Epoch 20/20, Batch 224/313, Loss: 0.1752
# Epoch 20/20, Batch 225/313, Loss: 0.1635
# Epoch 20/20, Batch 226/313, Loss: 0.2987
# Epoch 20/20, Batch 227/313, Loss: 0.2129
# Epoch 20/20, Batch 228/313, Loss: 0.1118
# Epoch 20/20, Batch 229/313, Loss: 0.0571
# Epoch 20/20, Batch 230/313, Loss: 0.0987
# Epoch 20/20, Batch 231/313, Loss: 0.1442
# Epoch 20/20, Batch 232/313, Loss: 0.1748
# Epoch 20/20, Batch 233/313, Loss: 0.1878
# Epoch 20/20, Batch 234/313, Loss: 0.1768
# Epoch 20/20, Batch 235/313, Loss: 0.1133
# Epoch 20/20, Batch 236/313, Loss: 0.0729
# Epoch 20/20, Batch 237/313, Loss: 0.1327
# Epoch 20/20, Batch 238/313, Loss: 0.1609
# Epoch 20/20, Batch 239/313, Loss: 0.2052
# Epoch 20/20, Batch 240/313, Loss: 0.1295
# Epoch 20/20, Batch 241/313, Loss: 0.1571
# Epoch 20/20, Batch 242/313, Loss: 0.1930
# Epoch 20/20, Batch 243/313, Loss: 0.0555
# Epoch 20/20, Batch 244/313, Loss: 0.2207
# Epoch 20/20, Batch 245/313, Loss: 0.0676
# Epoch 20/20, Batch 246/313, Loss: 0.2170
# Epoch 20/20, Batch 247/313, Loss: 0.1557
# Epoch 20/20, Batch 248/313, Loss: 0.2448
# Epoch 20/20, Batch 249/313, Loss: 0.1437
# Epoch 20/20, Batch 250/313, Loss: 0.2704
# Epoch 20/20, Batch 251/313, Loss: 0.0751
# Epoch 20/20, Batch 252/313, Loss: 0.1534
# Epoch 20/20, Batch 253/313, Loss: 0.1018
# Epoch 20/20, Batch 254/313, Loss: 0.0983
# Epoch 20/20, Batch 255/313, Loss: 0.1306
# Epoch 20/20, Batch 256/313, Loss: 0.0670
# Epoch 20/20, Batch 257/313, Loss: 0.1287
# Epoch 20/20, Batch 258/313, Loss: 0.1609
# Epoch 20/20, Batch 259/313, Loss: 0.1655
# Epoch 20/20, Batch 260/313, Loss: 0.1925
# Epoch 20/20, Batch 261/313, Loss: 0.3159
# Epoch 20/20, Batch 262/313, Loss: 0.1232
# Epoch 20/20, Batch 263/313, Loss: 0.1171
# Epoch 20/20, Batch 264/313, Loss: 0.4228
# Epoch 20/20, Batch 265/313, Loss: 0.1450
# Epoch 20/20, Batch 266/313, Loss: 0.1919
# Epoch 20/20, Batch 267/313, Loss: 0.1337
# Epoch 20/20, Batch 268/313, Loss: 0.1184
# Epoch 20/20, Batch 269/313, Loss: 0.0854
# Epoch 20/20, Batch 270/313, Loss: 0.1245
# Epoch 20/20, Batch 271/313, Loss: 0.1965
# Epoch 20/20, Batch 272/313, Loss: 0.1006
# Epoch 20/20, Batch 273/313, Loss: 0.2197
# Epoch 20/20, Batch 274/313, Loss: 0.1667
# Epoch 20/20, Batch 275/313, Loss: 0.1266
# Epoch 20/20, Batch 276/313, Loss: 0.1733
# Epoch 20/20, Batch 277/313, Loss: 0.1856
# Epoch 20/20, Batch 278/313, Loss: 0.1741
# Epoch 20/20, Batch 279/313, Loss: 0.1578
# Epoch 20/20, Batch 280/313, Loss: 0.1014
# Epoch 20/20, Batch 281/313, Loss: 0.1519
# Epoch 20/20, Batch 282/313, Loss: 0.1888
# Epoch 20/20, Batch 283/313, Loss: 0.2905
# Epoch 20/20, Batch 284/313, Loss: 0.1805
# Epoch 20/20, Batch 285/313, Loss: 0.0965
# Epoch 20/20, Batch 286/313, Loss: 0.1237
# Epoch 20/20, Batch 287/313, Loss: 0.3694
# Epoch 20/20, Batch 288/313, Loss: 0.1600
# Epoch 20/20, Batch 289/313, Loss: 0.1672
# Epoch 20/20, Batch 290/313, Loss: 0.2038
# Epoch 20/20, Batch 291/313, Loss: 0.1207
# Epoch 20/20, Batch 292/313, Loss: 0.1159
# Epoch 20/20, Batch 293/313, Loss: 0.3120
# Epoch 20/20, Batch 294/313, Loss: 0.1552
# Epoch 20/20, Batch 295/313, Loss: 0.1475
# Epoch 20/20, Batch 296/313, Loss: 0.1654
# Epoch 20/20, Batch 297/313, Loss: 0.2457
# Epoch 20/20, Batch 298/313, Loss: 0.1279
# Epoch 20/20, Batch 299/313, Loss: 0.1110
# Epoch 20/20, Batch 300/313, Loss: 0.1570
# Epoch 20/20, Batch 301/313, Loss: 0.2067
# Epoch 20/20, Batch 302/313, Loss: 0.1443
# Epoch 20/20, Batch 303/313, Loss: 0.1793
# Epoch 20/20, Batch 304/313, Loss: 0.2069
# Epoch 20/20, Batch 305/313, Loss: 0.1561
# Epoch 20/20, Batch 306/313, Loss: 0.1625
# Epoch 20/20, Batch 307/313, Loss: 0.1331
# Epoch 20/20, Batch 308/313, Loss: 0.2329
# Epoch 20/20, Batch 309/313, Loss: 0.0885
# Epoch 20/20, Batch 310/313, Loss: 0.1511
# Epoch 20/20, Batch 311/313, Loss: 0.1015
# Epoch 20/20, Batch 312/313, Loss: 0.1438
# Epoch 20/20, Batch 313/313, Loss: 0.0622
#
# Epoch 20/20 finished, Avg Loss: 0.1628
# Epoch 20/20, Validation Batch 1/79
# Epoch 20/20, Validation Batch 2/79
# Epoch 20/20, Validation Batch 3/79
# Epoch 20/20, Validation Batch 4/79
# Epoch 20/20, Validation Batch 5/79
# Epoch 20/20, Validation Batch 6/79
# Epoch 20/20, Validation Batch 7/79
# Epoch 20/20, Validation Batch 8/79
# Epoch 20/20, Validation Batch 9/79
# Epoch 20/20, Validation Batch 10/79
# Epoch 20/20, Validation Batch 11/79
# Epoch 20/20, Validation Batch 12/79
# Epoch 20/20, Validation Batch 13/79
# Epoch 20/20, Validation Batch 14/79
# Epoch 20/20, Validation Batch 15/79
# Epoch 20/20, Validation Batch 16/79
# Epoch 20/20, Validation Batch 17/79
# Epoch 20/20, Validation Batch 18/79
# Epoch 20/20, Validation Batch 19/79
# Epoch 20/20, Validation Batch 20/79
# Epoch 20/20, Validation Batch 21/79
# Epoch 20/20, Validation Batch 22/79
# Epoch 20/20, Validation Batch 23/79
# Epoch 20/20, Validation Batch 24/79
# Epoch 20/20, Validation Batch 25/79
# Epoch 20/20, Validation Batch 26/79
# Epoch 20/20, Validation Batch 27/79
# Epoch 20/20, Validation Batch 28/79
# Epoch 20/20, Validation Batch 29/79
# Epoch 20/20, Validation Batch 30/79
# Epoch 20/20, Validation Batch 31/79
# Epoch 20/20, Validation Batch 32/79
# Epoch 20/20, Validation Batch 33/79
# Epoch 20/20, Validation Batch 34/79
# Epoch 20/20, Validation Batch 35/79
# Epoch 20/20, Validation Batch 36/79
# Epoch 20/20, Validation Batch 37/79
# Epoch 20/20, Validation Batch 38/79
# Epoch 20/20, Validation Batch 39/79
# Epoch 20/20, Validation Batch 40/79
# Epoch 20/20, Validation Batch 41/79
# Epoch 20/20, Validation Batch 42/79
# Epoch 20/20, Validation Batch 43/79
# Epoch 20/20, Validation Batch 44/79
# Epoch 20/20, Validation Batch 45/79
# Epoch 20/20, Validation Batch 46/79
# Epoch 20/20, Validation Batch 47/79
# Epoch 20/20, Validation Batch 48/79
# Epoch 20/20, Validation Batch 49/79
# Epoch 20/20, Validation Batch 50/79
# Epoch 20/20, Validation Batch 51/79
# Epoch 20/20, Validation Batch 52/79
# Epoch 20/20, Validation Batch 53/79
# Epoch 20/20, Validation Batch 54/79
# Epoch 20/20, Validation Batch 55/79
# Epoch 20/20, Validation Batch 56/79
# Epoch 20/20, Validation Batch 57/79
# Epoch 20/20, Validation Batch 58/79
# Epoch 20/20, Validation Batch 59/79
# Epoch 20/20, Validation Batch 60/79
# Epoch 20/20, Validation Batch 61/79
# Epoch 20/20, Validation Batch 62/79
# Epoch 20/20, Validation Batch 63/79
# Epoch 20/20, Validation Batch 64/79
# Epoch 20/20, Validation Batch 65/79
# Epoch 20/20, Validation Batch 66/79
# Epoch 20/20, Validation Batch 67/79
# Epoch 20/20, Validation Batch 68/79
# Epoch 20/20, Validation Batch 69/79
# Epoch 20/20, Validation Batch 70/79
# Epoch 20/20, Validation Batch 71/79
# Epoch 20/20, Validation Batch 72/79
# Epoch 20/20, Validation Batch 73/79
# Epoch 20/20, Validation Batch 74/79
# Epoch 20/20, Validation Batch 75/79
# Epoch 20/20, Validation Batch 76/79
# Epoch 20/20, Validation Batch 77/79
# Epoch 20/20, Validation Batch 78/79
# Epoch 20/20, Validation Batch 79/79
#
# Validation Accuracy: 0.8720

# %% [markdown]
# ### **Let's evaluate the model**

# %%
from sklearn.metrics import f1_score, confusion_matrix
import numpy as np

model.eval()
model.to(device)

best_model_path = "best_model.pth"
model.load_state_dict(torch.load(best_model_path, map_location=device, weights_only=True))

all_preds = []
all_labels = []

test_texts = list(raw_dataset['test']['text'])
test_labels = list(raw_dataset['test']['label'])

test_encodings = tokenizer(
    test_texts,
    truncation=True,
    padding='max_length',
    max_length=max_seq_len,
    add_special_tokens=True,
)

test_dataset = MyDataset(test_encodings['input_ids'], test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

num_test_batches = len(test_dataloader)
with torch.no_grad():
    for j, (batch_token_ids, batch_labels) in enumerate(test_dataloader, 1):
        batch_token_ids = batch_token_ids.to(device)
        batch_labels = batch_labels.to(device)

        logits = model(batch_token_ids)  # (batch_size, num_classes)
        preds = logits.argmax(dim=1)     # (batch_size,)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(batch_labels.cpu().numpy())
        print(f"test Batch {j}/{num_test_batches}", end='\r')

# Accuracy
accuracy = (np.array(all_preds) == np.array(all_labels)).mean()
print(f"Test Accuracy: {accuracy:.4f}")

# F1 Score
f1 = f1_score(all_labels, all_preds, average='binary')
print(f"F1 Score: {f1:.4f}")

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
print("Confusion Matrix:")
print(cm)
# Out:
# Test Accuracy: 0.8567
# F1 Score: 0.8512
# Confusion Matrix:
# [[11173  1327]
#  [ 2255 10245]]
